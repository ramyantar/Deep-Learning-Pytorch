# %% [markdown]
# # Object Detection in a maritime context
#
# ## Introduction
#
# In this lab we want to go deeper into the comprehension and the use of object detection architectures by training maritime object detectors. We will start by training a Faster R-CNN object detector on a maritime Pascal VOC subset. Then we will redefine our need to retrain the model in a more efficient fashion. Then we'll analyse the performance of the model using metrics seen in class.
#
# ## Objectives
# - Learn to use an object detector in pytorch and evaluate it.
# - Select data and train a detector to meet an industry requirement.
#
# ## Getting started
#
# Load all the necessary packages before starting.

# %%
# import torch packages
import pandas as pd 
import torch
import torch.nn as nn
import os
import time
from pathlib import Path
from torch.autograd import Variable
from PIL import Image
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# import some common libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import files, drive

# %% [markdown]
# ## Exercise 1: What is the challenge ?
#
# For the Unmanned Surface Vehicle (USV) we want to be able to detect all surrounding floating objects and classify them into one of the following categories.
#
# 0. boat
# 1. buoy
# 2. sail
# 3. person
# 4. kayak
# 5. motor_sail
# 6. ferry
# 7. vessel
# 8. zodiac
# 9. fishing_boat
# 10. OFNI
# 11. kite
# 12. windsurf
# 13. surfboard
#
# For that purpose Eca Robotics has downloaded [Pascal VOC](http://host.robots.ox.ac.uk/pascal/VOC/) open dataset, filter only maritime images and reannotate them with interesting classes. Indeed Pascal VOC dataset only contains 20 categories and we kept images containing boat objects.
#
# **Can you train a maritime object detector with that dataset ?**
#
# Load the data and create stats on the classes to get a sense of the dataset.

# %%
# !gdown 1ik0v3VJosH9E_UX62nGxl-hi75t36knJ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ik0v3VJosH9E_UX62nGxl-hi75t36knJ
# To: /content/maritime_object_detection.tar
# 100% 59.6M/59.6M [00:01<00:00, 35.3MB/s]

# %%
# !tar -xf maritime_object_detection.tar

# %%
data_path = 'pascal_voc/train/'

# Create annotations dictionnary
anno_dict = {
    0: "boat",
    1: "buoy",
    2: "sail",
    3: "person",
    4: "kayak",
    5: "motor_sail",
    6: "ferry",
    7: "vessel",
    8: "zodiac",
    9: "fishing_boat",
    10: "OFNI",
    11: "kite",
    12: "windsurf",
    13: "surfboard"
}
for class_id, class_name in anno_dict.items():
    print(class_id, class_name)
# Out:
# 0 boat
# 1 buoy
# 2 sail
# 3 person
# 4 kayak
# 5 motor_sail
# 6 ferry
# 7 vessel
# 8 zodiac
# 9 fishing_boat
# 10 OFNI
# 11 kite
# 12 windsurf
# 13 surfboard

# %% [markdown]
# We show an image to see the nature of the images.

# %%
from PIL import Image
Image.open(data_path + '2007_000061.jpg')

a=Image.open(data_path + '2007_000061.jpg')
# print (a.size)

! cat pascal_voc/train/labels.txt
# Out:
# boat
# buoy
# sail
# person
# kayak
# motor_sail
# ferry
# vessel
# zodiac
# fishing_boat
# OFNI
# kite
# windsurf
# surfboard

# %% [markdown]
# We want to count the number of occurences of each class in the 500+ files we have at our disposal.
#
#
#
# ```
# TODO
# 1. read all txt files and iterate over them - Path and glob function,
# 2. filter labels.txt file,
# 3. using pandas to read column 0 and append it to the classes list,
# 4. concat the list into a pandas dataframe,
# 5. return the count using value_counts function
# ```

# %%
# Get annotations from txt files
def count_objects(data_path):
    """
    Function reading all yolo format txt files and returning number of objects by class

    <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
    <object-class> - integer number of object from 0 to (classes-1)
    <XCenterRelative> <YCenterRelative> - center of the bounding box [0,1]
    <WidthRelative> <HeightRelative> - width and height [0,1]
    """
    # Initialize an empty list to store the class labels
    classes = []
    # Use pathlib to access the directory specified by data_path
    dir = Path(data_path)
    # Use glob to get all the txt files in the directory
    txt_files = dir.glob("*.txt")
    # Iterate through the txt files and read the first column using pandas
    for file in txt_files:
        df = pd.read_csv(file, header=None, delimiter=' ')
        if file.name !='labels.txt':
            classes.append(df[0])
    # Concatenate the list of classes into a single DataFrame
    count_df = pd.concat(classes)
    # Get the count of each class and return the result
    counts = count_df.value_counts()
    return counts

# %%
count_df = count_objects(data_path)
# If assert launch an error there is an error in your code, else it is OK.
assert len(count_df) == 14
count_df
# Out:
# 3     572
# 0     416
# 4     170
# 2     165
# 1     149
# 5     139
# 6     113
# 7      66
# 9      55
# 8      37
# 10      8
# 12      3
# 11      2
# 13      1
# Name: 0, dtype: int64

# %% [markdown]
# To improve readability replace index by class names using the dictionnary anno_dict.
#
# ```
# TODO
# Replace index by class names with one command
# ```
#
# Hint : Use pandas.rename function.

# %%
### BEGIN SOLUTION
count_df =count_df.rename(anno_dict)
### END SOLUTION
assert count_df['sail'] == 165
count_df
# Out:
# person          572
# boat            416
# kayak           170
# sail            165
# buoy            149
# motor_sail      139
# ferry           113
# vessel           66
# fishing_boat     55
# zodiac           37
# OFNI              8
# windsurf          3
# kite              2
# surfboard         1
# Name: 0, dtype: int64

# %% [markdown]
# To improve the effectiveness of the TP we use a small dataset, which is still long to train. Futhermore the dataset is unbalanced, which is a difficulty to train a robust detector.
#
# In industrial applications several thousands of annotations by class are needed to obtain an acceptable performance. We'll keep that in mind when analysing results.

# %% [markdown]
# ## Exercise 2: Code a dataloader
#
# To exploit the images and their annotations, we need to write a dataloader in order to iterate through the images in the Pytorch format.
#
# The [torchvision reference scripts for training object detection, instance segmentation and person keypoint detection](https://github.com/pytorch/vision/tree/v0.3.0/references/detection) allows for easily supporting adding new custom datasets.
# The dataset should inherit from the standard `torch.utils.data.Dataset` class, and implement `__len__` and `__getitem__`.
#
# The only specificity that we require is that the dataset `__getitem__` should return:
#
# * image: a PIL Image of size (H, W)
# * target: a dict containing the following fields
#     * `boxes` (`FloatTensor[N, 4]`): the coordinates of the `N` bounding boxes in `[x0, y0, x1, y1]` format, ranging from `0` to `W` and `0` to `H`
#     * `labels` (`Int64Tensor[N]`): the label for each bounding box
#     * `image_id` (`Int64Tensor[1]`): an image identifier. It should be unique between all the images in the dataset, and is used during evaluation
#     * `area` (`Tensor[N]`): The area of the bounding box. This is used during evaluation with the COCO metric, to separate the metric scores between small, medium and large boxes.
#     * `iscrowd` (`UInt8Tensor[N]`): instances with `iscrowd=True` will be ignored during evaluation.
#     * (optionally) `masks` (`UInt8Tensor[N, H, W]`): The segmentation masks for each one of the objects
#     * (optionally) `keypoints` (`FloatTensor[N, K, 3]`): For each one of the `N` objects, it contains the `K` keypoints in `[x, y, visibility]` format, defining the object. `visibility=0` means that the keypoint is not visible. Note that for data augmentation, the notion of flipping a keypoint is dependent on the data representation, and you should probably adapt `references/detection/transforms.py` for your new keypoint representation
#
# If your model returns the above methods, they will make it work for both training and evaluation, and will use the evaluation scripts from pycocotools.
#
#
# One note on the labels. The model considers class 0 as background. **Then we need to modify class 0 - boat, in order to make a difference from the background. We will replace 0 by 14.**
#
# ```
# TODO
# Implement __getitem__ function by following comments in the code
# ```

# %%
class VocDataset(torch.utils.data.Dataset):
  def __init__(self, root, transform=None):
    self.root = root
    self.transform = transform
    # load all image files, sorting them to ensure that they are aligned
    self.imgs = list(sorted(Path(root).glob('*.jpg')))
    self.bboxes = list(sorted(Path(root).glob('*.txt')))[:-1] # ignore labels.txt

  def __getitem__(self, idx):

    # BEGIN SOLUTION
    # get image and bounding boxes paths
    img_path = self.imgs[idx]
    bbox_path =  self.bboxes[idx]
    img = Image.open(img_path).convert("RGB")
    # get width and height
    width, height = img.size
    # get bounding boxes
    bbox_df = pd.read_csv(bbox_path, header=None, sep=' ')

    # get bounding box coordinates
    # YOLO format reminder :
    # <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
    boxes = []
    for index, row in bbox_df.iterrows():
      xmin = (row[1] - row[3]/2)*width
      xmax = (row[1] + row[3]/2)*width
      ymin = (row[2] - row[4]/2)*height
      ymax =(row[2] + row[4]/2)*height 
      if xmin < xmax and ymin < ymax:
        boxes.append([xmin, ymin, xmax, ymax])

    # convert everything into a torch.Tensor
    boxes = torch.Tensor(boxes)
    # replace label 0 by 14
    labels = bbox_df[0].replace(0, 14)
    # convert labels to a torch.Tensor
    labels = torch.as_tensor(labels, dtype=torch.int64)

    # get image id
    image_id = torch.Tensor([idx])
    # compute area of the bounding boxes
    area = (boxes[:,2] - boxes[:,0])*(boxes[:,3] - boxes[:,1])  
    # suppose all instances are not crowd
    iscrowd = torch.zeros((len(bbox_df),), dtype=torch.int64)

    # populate target dictionnary
    target = {}
    target["boxes"] = boxes
    target["labels"] =  labels
    target["image_id"] = image_id
    target["area"] = area
    target["iscrowd"] = iscrowd

    ### END SOLUTION

    # image transformation
    if self.transform is not None:
      img, target = self.transform(img, target)

    return img, target


  def __len__(self):
    return len(self.imgs)

# %% [markdown]
# Let now get the result tuple for the first image and plot it with ground truth annotations to see if the data seems correctly read.

# %%
dataset = VocDataset(data_path)
assert torch.equal(dataset[2][1]['area'], torch.tensor([22363.4668]))
assert torch.equal(dataset[1][1]['labels'], torch.tensor([14, 5, 14]))
dataset[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=500x333 at 0x7F34F3CD0040>,
#  {'boxes': tensor([[274.0000,  10.9998, 437.0000, 278.9999],
#           [187.3420, 214.0001, 281.0000, 252.0001]]),
#   'labels': tensor([5, 6]),
#   'image_id': tensor([0.]),
#   'area': tensor([43684.0117,  3559.0000]),
#   'iscrowd': tensor([0, 0])})

# %%
import torchvision.transforms.functional as F

plt.rcParams["savefig.bbox"] = 'tight'

def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
from torchvision.io import read_image
from torchvision.utils import draw_bounding_boxes

img1_int = read_image(data_path + '/2007_000061.jpg')
colors = ["yellow", "red"]
result = draw_bounding_boxes(img1_int, dataset[0][1]['boxes'], colors=colors, width=5)
show(result)

# %%
img2_int = read_image(data_path + '/2007_000241.jpg')
colors = ["blue", "yellow", "blue"]
result = draw_bounding_boxes(img2_int, dataset[1][1]['boxes'], colors=colors, width=5)
show(result)

# %% [markdown]
# The dataloader seems to do the job. If you are curious about the dataset you can plot other images, or create a grib with several ones.

# %% [markdown]
# ## Exercise 3: Define a model
#
# In this tutorial, we will be using faster R-CNN as described in class. Faster R-CNN is a model that predicts both bounding boxes and class scores for potential objects in the image.
#
# ![Faster R-CNN](https://www.researchgate.net/profile/Zhipeng-Deng-2/publication/324903264/figure/fig2/AS:640145124499471@1529633899620/The-architecture-of-Faster-R-CNN.png)
#
# There are two common situations where one might want to modify one of the available models in torchvision modelzoo. The first is when we want to start from a pre-trained model, and just finetune the last layer. The other is when we want to replace the backbone of the model with a different one (for faster predictions, for example).
#
# We are in the first case to use all the power of a pretrained model. We'll load Faster R-CNN with pretrained weights before retraining it on the images we have. By that means we accelerate the training of the model.
#
# ```
# TODO
# 1. load a pretrained fasterrcnn_resnet50_fpn
# 2. get number of input features for the classifier
# 3. replace the pre-trained head with a new one
# ```

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn, FasterRCNN_ResNet50_FPN_Weights

def get_detection_model(num_classes=15):

  ### BEGIN SOLUTION

  # load a model pre-trained on COCO
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
  # get number of input features for the classifier
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  # replace the pre-trained head with a new one
  model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)

  ### END SOLUTION

  return model

# %%
model = get_detection_model()
model
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
#   0%|          | 0.00/160M [00:00<?, ?B/s]
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=15, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=60, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Exercise 4: Preparing training loop
#
# In references/detection/, we have a number of helper functions to simplify training and evaluating detection models. Here, we will use references/detection/engine.py, references/detection/utils.py and references/detection/transforms.py.
#
# Let's copy those files (and their dependencies) in here so that they are available in the notebook

# %%
# %%shell
#
# # Download TorchVision repo to use some files from
# # references/detection
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.8.2
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 289636, done.
# remote: Counting objects: 100% (10762/10762), done.
# remote: Compressing objects: 100% (699/699), done.
# remote: Total 289636 (delta 10110), reused 10637 (delta 10039), pack-reused 278874
# Receiving objects: 100% (289636/289636), 584.89 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (265212/265212), done.
# Note: switching to 'v0.8.2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 2f40a483d7 [v0.8.X] .circleci: Add Python 3.9 to CI (#3063)

# %% [markdown]
# ### Data augmentation
#
# To go deeper into the training process we want to do data augmentation by applying random transformations to the images. It allows the model to train longer without overfitting and augment programmatically the dataset size and the genericity of the model.
#
# You can find the reference of the transformations here: https://pytorch.org/vision/stable/transforms.html

# %%
import transforms as T

def get_transform(train):
    transform = []
    # converts the image, a PIL image, into a PyTorch Tensor
    # transform.append(transforms.ToTensor())
    transform.append(T.ToTensor())
    if train:

      ### BEGIN SOLUTION

      # during training randomly horizontal flip the training images - proba 0.5
      transform.append(T.RandomHorizontalFlip(0.5))
      ## END SOLUTION

    return T.Compose(transform)

# %% [markdown]
# ### Testing forward() method
#
# Before iterating over the dataset, it’s good to see what the model expects during training and inference time on sample data.
#
# ```
# TODO
# Follow the comments on the next cell
# ```

# %%
import utils

### BEGIN SOLUTION

# get model and dataset with augmentations
model = get_detection_model()
dataset =  VocDataset(data_path, get_transform(train=True))

# create dataloader with torch.utils.data.DataLoader
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn
)

# For training
# get next batch images + targets by iterating on the data_loader
images, targets = next(iter(data_loader))
# Convert images and targets into the desired format by the model
# Hint : use list comprehension
images =   list([img for img in images]) # look expected images values https://pytorch.org/vision/main/models/generated/torchvision.models.detection.fasterrcnn_resnet50_fpn.html#torchvision.models.detection.fasterrcnn_resnet50_fpn
targets =   [{k: v for k, v in t.items()} for t in targets] # look expected targets values https://pytorch.org/vision/main/models/generated/torchvision.models.detection.fasterrcnn_resnet50_fpn.html#torchvision.models.detection.fasterrcnn_resnet50_fpn
output = model(images, targets)   # Returns losses and detections

### END SOLUTION

# %%
# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x) # Returns predictions
predictions
# Out:
# [{'boxes': tensor([[ 82.1412,   0.0000, 397.1208, 181.9945],
#           [ 68.9907, 118.6335, 399.8573, 300.0000],
#           [ 70.5854,  65.9140,  74.0160,  70.6960],
#           [167.0256, 101.6013, 169.9874, 105.0588],
#           [168.0648, 101.9351, 171.3041, 105.8150],
#           [173.7889,  96.4983, 176.9655,  99.6114],
#           [ 71.5613,  64.8036,  74.7201,  69.6867],
#           [169.1796,  97.7750, 172.5001, 100.7626],
#           [165.6006, 101.2645, 168.3766, 104.4184],
#           [166.9864, 102.9750, 169.9644, 106.7453],
#           [169.3425, 102.0854, 172.3994, 105.7296],
#           [137.6156, 100.6809, 140.9619, 103.8402],
#           [174.3553, 102.5986, 177.1814, 105.8126],
#           [192.7075,  80.1039, 400.0000, 265.3915],
#           [173.9957, 101.0666, 176.8109, 104.1952],
#           [172.8177,  95.7881, 176.2662,  99.0228],
#           [170.7115, 101.6153, 173.9027, 105.2491],
#           [139.3111, 136.9662, 142.8592, 140.9084],
#           [173.8044,  95.5039, 177.2776,  98.7141],
#           [170.1122,  98.5385, 173.6082, 101.8074],
#           [ 60.6953, 158.2433,  63.9451, 161.7540],
#           [169.3359, 100.7289, 172.2448, 104.0703],
#           [ 59.1444, 158.0701,  62.1979, 161.6478],
#           [145.4643, 132.3079, 148.3002, 135.8909],
#           [262.6200, 108.5477, 266.3271, 112.8614],
#           [175.1611,  95.5967, 177.9706,  98.6209],
#           [336.3406, 167.8772, 339.6321, 171.3969],
#           [167.6986,  99.9888, 170.7548, 103.1490],
#           [147.1481, 132.2375, 150.0480, 135.8476],
#           [160.5771,  97.1204, 163.3296, 100.6749],
#           [ 70.9512,  63.5046,  73.9521,  67.5514],
#           [172.7872,  96.8133, 176.0344, 100.0272],
#           [ 61.3945, 157.3911,  64.6876, 161.0954],
#           [171.9179,  95.7795, 174.8372,  98.9242],
#           [145.4803, 134.2473, 148.2754, 137.7886],
#           [337.5326, 167.7098, 340.9634, 171.1188],
#           [164.0678, 101.3479, 166.7221, 104.4476],
#           [173.7802,  93.6838, 177.3365,  96.7437],
#           [173.7886,  97.5365, 176.9256, 100.6293],
#           [171.8683,  96.9230, 174.7640, 100.2754],
#           [171.8869,  93.7605, 174.8130,  96.8045],
#           [172.2859, 102.5218, 175.2515, 105.7965],
#           [ 61.5439, 159.1869,  64.7524, 162.8678],
#           [167.0842, 234.3512, 400.0000, 290.9011],
#           [ 59.2333, 159.3571,  62.2517, 163.1035],
#           [ 90.0395, 161.0702,  93.5874, 165.5766],
#           [173.6928,  99.2852, 176.8664, 102.3150],
#           [160.5062,  95.8616, 163.3154,  99.3969],
#           [162.2800,  96.0338, 165.0118,  99.6434],
#           [235.8103,  99.4381, 239.1676, 103.2160],
#           [171.1040,  97.7992, 174.4608, 100.8080],
#           [167.4296,  98.4744, 170.8519, 101.4502],
#           [173.8800,  90.0962, 177.7029,  93.9146],
#           [336.1821, 172.8706, 338.8864, 176.2305],
#           [ 62.2529, 161.5677,  65.2414, 164.9925],
#           [ 65.5054, 164.0662, 390.0665, 298.0809],
#           [166.4666,  98.3236, 169.2600, 101.3909],
#           [174.9363,  93.4885, 178.2505,  96.5913],
#           [ 62.7502, 158.4528,  65.9950, 162.2205],
#           [208.8397,  27.0942, 398.5646, 140.2191],
#           [235.9393,  97.8722, 239.3408, 101.4329],
#           [ 62.8836, 159.9423,  66.0532, 163.6926],
#           [166.5666,  99.3889, 169.3598, 102.3455],
#           [211.4890, 136.4888, 215.3683, 140.8006],
#           [148.8770, 132.0512, 151.6714, 135.8032],
#           [ 61.4098, 160.1335,  64.4688, 164.1427],
#           [139.3639, 144.3331, 143.0976, 148.0650],
#           [336.1820, 169.0650, 339.3492, 172.3982],
#           [195.0178,  93.7811, 393.3540, 300.0000],
#           [ 59.0719, 156.8055,  62.0332, 160.3840],
#           [337.6214, 168.8940, 340.7175, 172.1161],
#           [220.6370, 233.7654, 224.6836, 239.8919],
#           [139.0622, 144.4819, 143.2124, 148.5496],
#           [ 98.7277, 123.1736, 101.5835, 126.5655],
#           [336.1986, 170.7700, 339.2020, 174.0799],
#           [147.1464, 134.2481, 150.0811, 137.8512],
#           [ 88.9478, 160.9111,  92.4272, 165.6484],
#           [ 98.7052, 124.2287, 101.5899, 127.8211],
#           [165.1122,  99.2936, 167.8159, 102.3459],
#           [105.7897, 120.8895, 109.1276, 124.5984],
#           [158.9301,  96.5060, 161.9849,  99.9824],
#           [ 68.9623, 156.7462,  71.7591, 160.3011],
#           [141.0069, 136.3181, 144.2296, 140.2694],
#           [108.3769,  65.1632, 111.3458,  69.3172],
#           [171.1172,  89.4123, 174.4243,  93.1543],
#           [256.6530,  64.8755, 259.9845,  70.2277],
#           [163.3505,  97.1249, 166.1351, 100.6114],
#           [217.2207,  62.2934, 220.2769,  66.0500],
#           [216.0482,  61.9713, 219.2070,  65.7664],
#           [172.7171,  88.8375, 176.4524,  92.5370],
#           [252.3703,   0.9039, 392.8633, 277.9836],
#           [172.4130, 100.7043, 175.3782, 103.9932],
#           [160.4986, 100.8195, 163.0940, 103.9578],
#           [162.3797, 101.0486, 164.9633, 104.1256],
#           [337.7546, 173.5919, 340.4625, 176.7989],
#           [337.7422, 170.4814, 340.7380, 173.7039],
#           [  0.0000, 208.4177, 368.6479, 300.0000],
#           [143.6934, 132.4302, 146.6709, 136.1723],
#           [ 68.9254, 158.4364,  71.7639, 162.2442],
#           [ 72.3454,  63.1283,  75.1951,  67.3329]], grad_fn=<StackBackward0>),
#   'labels': tensor([10, 10,  2, 12, 12, 12,  2, 12, 12, 12, 12, 12, 12, 10, 12, 12, 12, 12,
#           12, 12, 12, 12, 12, 12,  9, 12, 12, 12, 12, 12,  2, 12, 12, 12, 12, 12,
#           12, 12, 12, 12, 12, 12, 12, 10, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,
#           12,  4, 12, 12, 12, 10, 12, 12, 12, 12, 12, 12, 12, 12,  4, 12, 12,  2,
#            4, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,  2, 12,  2, 12, 12, 12, 12,
#            4, 12, 12, 12, 12, 12, 10, 12, 12,  2]),
#   'scores': tensor([0.1268, 0.1243, 0.1232, 0.1227, 0.1214, 0.1194, 0.1186, 0.1184, 0.1174,
#           0.1165, 0.1164, 0.1164, 0.1163, 0.1158, 0.1158, 0.1155, 0.1154, 0.1151,
#           0.1149, 0.1146, 0.1143, 0.1143, 0.1142, 0.1141, 0.1137, 0.1133, 0.1129,
#           0.1128, 0.1127, 0.1126, 0.1125, 0.1122, 0.1121, 0.1119, 0.1117, 0.1115,
#           0.1109, 0.1107, 0.1105, 0.1104, 0.1104, 0.1103, 0.1101, 0.1100, 0.1098,
#           0.1096, 0.1096, 0.1095, 0.1095, 0.1092, 0.1092, 0.1088, 0.1087, 0.1085,
#           0.1085, 0.1084, 0.1084, 0.1083, 0.1083, 0.1082, 0.1081, 0.1080, 0.1080,
#           0.1079, 0.1079, 0.1079, 0.1079, 0.1077, 0.1076, 0.1075, 0.1074, 0.1073,
#           0.1072, 0.1069, 0.1069, 0.1067, 0.1064, 0.1062, 0.1062, 0.1062, 0.1061,
#           0.1058, 0.1058, 0.1058, 0.1057, 0.1057, 0.1056, 0.1055, 0.1053, 0.1053,
#           0.1053, 0.1052, 0.1052, 0.1050, 0.1050, 0.1050, 0.1050, 0.1049, 0.1049,
#           0.1049], grad_fn=<IndexBackward0>)},
#  {'boxes': tensor([[ 89.4130, 359.5046,  93.4725, 363.5336],
#           [ 88.1437, 359.4292,  92.0632, 363.1787],
#           [ 90.5138, 351.0243,  94.1054, 355.4852],
#           [117.3838,   0.0000, 397.1845, 233.2602],
#           [115.7509, 356.8578, 119.8309, 361.9068],
#           [112.1337, 112.2720, 116.0253, 116.7162],
#           [ 90.3412, 353.8072,  93.9478, 358.0910],
#           [ 89.6477, 356.7180,  93.5720, 360.7510],
#           [224.8985,  81.0738, 229.2890,  87.0266],
#           [ 86.9516, 358.6040,  90.4493, 362.2946],
#           [223.1445,  80.5314, 227.7172,  86.2930],
#           [ 88.4978, 356.4738,  92.1978, 360.2476],
#           [143.6732, 129.4887, 147.2259, 133.5128],
#           [ 92.5277, 351.5251,  96.3748, 355.9587],
#           [111.6825, 353.2870, 115.5842, 357.4585],
#           [124.3815, 228.5217, 399.9396, 500.0000],
#           [ 24.5759, 314.3261, 394.2673, 500.0000],
#           [143.7670, 130.6646, 147.3480, 135.0800],
#           [120.2799, 114.3631, 123.9020, 118.5895],
#           [141.0178, 403.8822, 400.0000, 488.4506],
#           [113.9984, 112.7936, 117.7589, 117.0766],
#           [113.9207, 355.3912, 117.8988, 359.8405],
#           [111.8119, 354.7888, 115.7471, 359.0778],
#           [ 36.8038, 444.1746, 384.5502, 494.6142],
#           [109.7776, 113.8991, 113.5208, 118.2317],
#           [224.7511,  78.9398, 229.1475,  85.2730],
#           [145.7366, 129.0823, 149.3886, 133.2070],
#           [112.2436, 358.4017, 116.3582, 363.3566],
#           [117.8604, 116.5741, 121.5489, 120.6193],
#           [113.9880, 357.1346, 118.1429, 361.9370],
#           [120.2220, 117.0332, 123.8664, 121.2275],
#           [ 91.5377, 358.6775,  95.3518, 362.6104],
#           [117.8101, 113.8685, 121.4279, 118.0256],
#           [112.1837, 356.9326, 116.1859, 361.6124],
#           [224.9244,  83.0632, 229.4466,  88.9324],
#           [188.2913,  99.7447, 192.8271, 104.2062],
#           [112.1481, 114.3528, 115.8207, 118.6235],
#           [211.5394, 258.8968, 215.3018, 263.0188],
#           [186.2057,  97.9261, 190.5237, 102.0937],
#           [124.1861,  93.9423, 398.2160, 333.0643],
#           [251.2722, 338.6400, 387.5542, 488.6282],
#           [117.9358, 118.9187, 121.8743, 122.8312],
#           [188.3709,  97.8248, 192.7176, 102.1414],
#           [115.9990, 113.1871, 119.6750, 117.3461],
#           [188.2713, 101.4712, 192.7900, 105.9067],
#           [145.7681, 130.4528, 149.5289, 134.9552],
#           [143.4993, 127.6989, 147.3632, 131.5234],
#           [118.8714,  84.0730, 359.4573, 471.8061],
#           [ 44.5933, 230.9896, 383.8134, 488.2537],
#           [ 91.7503, 356.8321,  95.4570, 360.7804],
#           [ 94.3420, 351.7569,  98.2926, 356.0268],
#           [147.7102, 128.5997, 151.4138, 132.7201],
#           [246.4026,  97.0247, 250.6338, 101.6568],
#           [189.7746,  99.5771, 194.1912, 104.1167],
#           [221.1530,  78.9733, 226.6478,  85.3559],
#           [147.6803, 130.0851, 151.4819, 134.4696],
#           [121.2145, 118.1797, 125.2567, 122.2935],
#           [119.7868, 119.0949, 123.5768, 123.1715],
#           [222.8448,  78.1284, 227.5899,  84.3807],
#           [118.4056, 119.7088, 122.8843, 123.6439],
#           [298.1758, 244.2856, 392.2509, 500.0000],
#           [116.6024, 295.0638, 121.3890, 300.3806],
#           [ 92.2845, 354.4745,  95.9657, 358.6662],
#           [  0.0000, 448.9112, 383.3044, 499.2337],
#           [213.5569, 255.5598, 217.5402, 259.7409],
#           [122.3564, 116.8966, 126.2126, 121.2178],
#           [221.4823,  87.5198, 225.9418,  92.8679],
#           [ 96.5143, 352.1221, 100.2890, 356.3031],
#           [110.5631, 357.8412, 114.8767, 361.8420],
#           [224.8810,  86.1657, 229.4313,  91.9102],
#           [116.4509, 117.5290, 120.2045, 121.4107],
#           [116.1139, 115.4623, 119.7369, 119.4525],
#           [117.8399, 120.6363, 121.9714, 124.6381],
#           [118.6527, 293.4381, 123.2932, 298.2622],
#           [189.8731,  97.8343, 194.0552, 102.1497],
#           [246.7460,  94.3207, 250.9627,  98.8154],
#           [171.7260, 105.0302, 176.7138, 109.2580],
#           [145.6682, 127.3180, 149.4756, 131.2576],
#           [101.4558, 352.4005, 105.1962, 356.9749],
#           [234.0453, 401.9013, 238.6013, 407.5568],
#           [141.2025, 129.7681, 144.9191, 133.8457],
#           [114.1647, 114.8001, 117.8071, 118.9333],
#           [119.1618, 291.4873, 123.9173, 296.6583],
#           [129.8292, 114.1199, 133.5002, 118.2706],
#           [223.1470,  86.2861, 227.7282,  91.7963],
#           [143.9336, 132.3468, 147.4797, 136.9471],
#           [107.6833, 113.9361, 111.5268, 118.2737],
#           [265.0143,  93.6271, 397.7961, 500.0000],
#           [223.3016,  83.1112, 227.9275,  88.7510],
#           [141.3052, 128.2882, 145.1599, 132.1912],
#           [117.1911, 296.8217, 122.2876, 301.9508],
#           [308.0088, 206.7989, 312.7468, 214.8685],
#           [117.2263, 121.8971, 121.8862, 125.7866],
#           [132.3684, 113.8939, 136.1543, 118.0329],
#           [119.9644, 351.7163, 124.2085, 356.4866],
#           [109.7284, 352.0777, 113.7842, 356.5264],
#           [149.7628, 128.0123, 153.5513, 132.2482],
#           [175.1895,  95.9553, 179.8654, 100.2386],
#           [118.8379, 121.7461, 123.2621, 125.6604],
#           [122.2147, 123.2970, 126.4830, 127.0023]], grad_fn=<StackBackward0>),
#   'labels': tensor([12, 12, 12, 10, 12, 12, 12, 12,  9, 12,  9, 12, 12, 12, 12, 10,  4, 12,
#           12, 10, 12, 12, 12,  4, 12,  9, 12, 12, 12, 12, 12, 12, 12, 12,  9, 12,
#           12, 12, 12, 10,  4, 12, 12, 12, 12, 12, 12,  9,  9, 12, 12, 12, 12, 12,
#            9, 12, 12, 12,  9, 12,  4, 12, 12, 10, 12, 12,  9, 12, 12,  9, 12, 12,
#           12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12,  9, 12, 12,  4,  9, 12,
#           12, 12, 12, 12, 12, 12, 12, 12, 12, 12]),
#   'scores': tensor([0.1262, 0.1236, 0.1217, 0.1194, 0.1186, 0.1174, 0.1173, 0.1169, 0.1166,
#           0.1162, 0.1159, 0.1157, 0.1150, 0.1148, 0.1145, 0.1144, 0.1140, 0.1137,
#           0.1136, 0.1135, 0.1134, 0.1134, 0.1133, 0.1132, 0.1127, 0.1127, 0.1119,
#           0.1118, 0.1117, 0.1116, 0.1115, 0.1114, 0.1113, 0.1113, 0.1112, 0.1110,
#           0.1110, 0.1109, 0.1108, 0.1108, 0.1104, 0.1103, 0.1097, 0.1097, 0.1097,
#           0.1096, 0.1095, 0.1093, 0.1092, 0.1091, 0.1089, 0.1087, 0.1087, 0.1087,
#           0.1087, 0.1085, 0.1084, 0.1083, 0.1083, 0.1083, 0.1082, 0.1081, 0.1079,
#           0.1079, 0.1079, 0.1078, 0.1078, 0.1078, 0.1076, 0.1076, 0.1074, 0.1070,
#           0.1070, 0.1069, 0.1069, 0.1068, 0.1068, 0.1068, 0.1067, 0.1066, 0.1066,
#           0.1066, 0.1063, 0.1063, 0.1063, 0.1062, 0.1062, 0.1060, 0.1060, 0.1060,
#           0.1060, 0.1059, 0.1058, 0.1057, 0.1057, 0.1055, 0.1055, 0.1054, 0.1054,
#           0.1051], grad_fn=<IndexBackward0>)}]

# %% [markdown]
# Note that we do not need to add a mean/std normalization nor image rescaling in the data transforms, as those are handled internally by the Faster R-CNN model.

# %% [markdown]
# ## Exercise 5: Putting everything together
#
# We now have the dataset class, the model, the data transform and a hint about the dataloader. Let's instantiate them to launch a full training process.
#
# First we want to create train/test split for the training and apply dataloaders to each one.

# %%
from engine import train_one_epoch, evaluate

### BEGIN SOLUTION

# use our dataset and defined transformations
dataset = VocDataset(data_path, get_transform(train=True))
dataset_test = VocDataset(data_path, get_transform(train=False))

# split the dataset in train and test set with torch.utils.data.Subset
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset,indices[:int(len(indices)*0.8)] )
dataset_test = torch.utils.data.Subset(dataset,indices[int(len(indices)*0.8):] )

from torch.utils.data import DataLoader
# define training and validation data loaders
data_loader = DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn,
 )# use a batch_size of 4, 2 workers and the shuffle option

data_loader_test = DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn,
 )  # use a batch_size of 2, 2 workers and disable the shuffle option

### END SOLUTION

# %% [markdown]
# Then, instantiate the model and the optimizer.

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has 14 classes but bg class is set to 0
num_classes = 15

### BEGIN SOLUTION

# get the model using our helper function
model = get_detection_model()
model = model.to(device)
# move model to the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# construct an optimizer SGD with lr=0.005, momentum=0.9 and weight_decay=0.0005
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.SGD(model.parameters(), lr=0.005, weight_decay=0.0005)
optimizer = torch.optim.SGD(params, lr = 0.005, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

### END SOLUTION

# %% [markdown]
# And now let's train the model for 3 epochs, evaluating at the end of every epoch.
#
# It's time for you to take a 20 min break during the training.

# %%
# let's train it for 3 epochs
num_epochs = 3

### BEGIN SOLUTION

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

### END SOLUTION
# Out:
# Epoch: [0]  [  0/220]  eta: 0:27:50  lr: 0.000028  loss: 2.8806 (2.8806)  loss_classifier: 2.7214 (2.7214)  loss_box_reg: 0.1405 (0.1405)  loss_objectness: 0.0112 (0.0112)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 7.5912  data: 0.1647  max mem: 2787
# Epoch: [0]  [ 10/220]  eta: 0:04:15  lr: 0.000256  loss: 2.8940 (2.9728)  loss_classifier: 2.6690 (2.6991)  loss_box_reg: 0.2109 (0.2362)  loss_objectness: 0.0112 (0.0183)  loss_rpn_box_reg: 0.0108 (0.0192)  time: 1.2150  data: 0.0227  max mem: 3530
# Epoch: [0]  [ 20/220]  eta: 0:02:59  lr: 0.000484  loss: 2.8231 (2.8102)  loss_classifier: 2.4122 (2.4384)  loss_box_reg: 0.2731 (0.3275)  loss_objectness: 0.0132 (0.0208)  loss_rpn_box_reg: 0.0147 (0.0234)  time: 0.5634  data: 0.0079  max mem: 3530
# Epoch: [0]  [ 30/220]  eta: 0:02:29  lr: 0.000712  loss: 2.0829 (2.4344)  loss_classifier: 1.7146 (2.0655)  loss_box_reg: 0.3044 (0.3197)  loss_objectness: 0.0132 (0.0251)  loss_rpn_box_reg: 0.0197 (0.0240)  time: 0.5497  data: 0.0073  max mem: 3530
# Epoch: [0]  [ 40/220]  eta: 0:02:11  lr: 0.000940  loss: 1.4059 (2.1386)  loss_classifier: 0.8904 (1.7423)  loss_box_reg: 0.2956 (0.3387)  loss_objectness: 0.0140 (0.0336)  loss_rpn_box_reg: 0.0200 (0.0241)  time: 0.5511  data: 0.0078  max mem: 3530
# Epoch: [0]  [ 50/220]  eta: 0:01:57  lr: 0.001168  loss: 0.9821 (1.9240)  loss_classifier: 0.6301 (1.5152)  loss_box_reg: 0.3257 (0.3529)  loss_objectness: 0.0164 (0.0295)  loss_rpn_box_reg: 0.0181 (0.0264)  time: 0.5444  data: 0.0078  max mem: 3530
# Epoch: [0]  [ 60/220]  eta: 0:01:46  lr: 0.001396  loss: 0.8227 (1.7445)  loss_classifier: 0.4795 (1.3409)  loss_box_reg: 0.3257 (0.3516)  loss_objectness: 0.0071 (0.0259)  loss_rpn_box_reg: 0.0129 (0.0261)  time: 0.5335  data: 0.0077  max mem: 3530
# Epoch: [0]  [ 70/220]  eta: 0:01:37  lr: 0.001624  loss: 0.7685 (1.6068)  loss_classifier: 0.3925 (1.2103)  loss_box_reg: 0.2844 (0.3439)  loss_objectness: 0.0108 (0.0265)  loss_rpn_box_reg: 0.0174 (0.0261)  time: 0.5458  data: 0.0079  max mem: 3530
# Epoch: [0]  [ 80/220]  eta: 0:01:29  lr: 0.001852  loss: 0.7135 (1.5039)  loss_classifier: 0.3994 (1.1127)  loss_box_reg: 0.2824 (0.3420)  loss_objectness: 0.0176 (0.0250)  loss_rpn_box_reg: 0.0125 (0.0242)  time: 0.5541  data: 0.0075  max mem: 3530
# Epoch: [0]  [ 90/220]  eta: 0:01:22  lr: 0.002081  loss: 0.7449 (1.4422)  loss_classifier: 0.4100 (1.0425)  loss_box_reg: 0.3144 (0.3490)  loss_objectness: 0.0116 (0.0256)  loss_rpn_box_reg: 0.0103 (0.0251)  time: 0.5849  data: 0.0076  max mem: 3590
# Epoch: [0]  [100/220]  eta: 0:01:15  lr: 0.002309  loss: 0.6931 (1.3824)  loss_classifier: 0.3573 (0.9825)  loss_box_reg: 0.3132 (0.3473)  loss_objectness: 0.0132 (0.0270)  loss_rpn_box_reg: 0.0185 (0.0255)  time: 0.5890  data: 0.0076  max mem: 3590
# Epoch: [0]  [110/220]  eta: 0:01:08  lr: 0.002537  loss: 0.6749 (1.3987)  loss_classifier: 0.3573 (0.9362)  loss_box_reg: 0.2994 (0.3542)  loss_objectness: 0.0224 (0.0660)  loss_rpn_box_reg: 0.0279 (0.0423)  time: 0.5456  data: 0.0074  max mem: 3590
# Epoch: [0]  [120/220]  eta: 0:01:01  lr: 0.002765  loss: 0.8025 (1.3495)  loss_classifier: 0.3717 (0.8898)  loss_box_reg: 0.3155 (0.3516)  loss_objectness: 0.0224 (0.0666)  loss_rpn_box_reg: 0.0235 (0.0415)  time: 0.5495  data: 0.0081  max mem: 3590
# Epoch: [0]  [130/220]  eta: 0:00:54  lr: 0.002993  loss: 0.5765 (1.2863)  loss_classifier: 0.2988 (0.8425)  loss_box_reg: 0.2565 (0.3424)  loss_objectness: 0.0201 (0.0626)  loss_rpn_box_reg: 0.0067 (0.0388)  time: 0.5590  data: 0.0080  max mem: 3590
# Epoch: [0]  [140/220]  eta: 0:00:48  lr: 0.003221  loss: 0.6101 (1.2531)  loss_classifier: 0.2924 (0.8095)  loss_box_reg: 0.2684 (0.3445)  loss_objectness: 0.0161 (0.0613)  loss_rpn_box_reg: 0.0082 (0.0378)  time: 0.5604  data: 0.0071  max mem: 3590
# Epoch: [0]  [150/220]  eta: 0:00:42  lr: 0.003449  loss: 0.7848 (1.2221)  loss_classifier: 0.3282 (0.7796)  loss_box_reg: 0.3024 (0.3457)  loss_objectness: 0.0186 (0.0587)  loss_rpn_box_reg: 0.0272 (0.0381)  time: 0.5572  data: 0.0088  max mem: 3590
# Epoch: [0]  [160/220]  eta: 0:00:36  lr: 0.003677  loss: 0.6375 (1.1884)  loss_classifier: 0.2839 (0.7504)  loss_box_reg: 0.2761 (0.3443)  loss_objectness: 0.0121 (0.0563)  loss_rpn_box_reg: 0.0151 (0.0373)  time: 0.5502  data: 0.0088  max mem: 3590
# Epoch: [0]  [170/220]  eta: 0:00:29  lr: 0.003905  loss: 0.5573 (1.1534)  loss_classifier: 0.2234 (0.7221)  loss_box_reg: 0.2519 (0.3411)  loss_objectness: 0.0079 (0.0535)  loss_rpn_box_reg: 0.0114 (0.0367)  time: 0.5672  data: 0.0072  max mem: 3590
# Epoch: [0]  [180/220]  eta: 0:00:23  lr: 0.004133  loss: 0.5942 (1.1432)  loss_classifier: 0.2372 (0.7037)  loss_box_reg: 0.3144 (0.3438)  loss_objectness: 0.0100 (0.0555)  loss_rpn_box_reg: 0.0114 (0.0401)  time: 0.5756  data: 0.0073  max mem: 3590
# Epoch: [0]  [190/220]  eta: 0:00:17  lr: 0.004361  loss: 0.6558 (1.1132)  loss_classifier: 0.2705 (0.6792)  loss_box_reg: 0.3164 (0.3397)  loss_objectness: 0.0355 (0.0552)  loss_rpn_box_reg: 0.0114 (0.0391)  time: 0.5733  data: 0.0072  max mem: 3590
# Epoch: [0]  [200/220]  eta: 0:00:11  lr: 0.004589  loss: 0.6753 (1.1052)  loss_classifier: 0.2705 (0.6671)  loss_box_reg: 0.3231 (0.3439)  loss_objectness: 0.0419 (0.0549)  loss_rpn_box_reg: 0.0217 (0.0394)  time: 0.5611  data: 0.0071  max mem: 3590
# Epoch: [0]  [210/220]  eta: 0:00:05  lr: 0.004818  loss: 0.9211 (1.0922)  loss_classifier: 0.3851 (0.6529)  loss_box_reg: 0.4606 (0.3462)  loss_objectness: 0.0319 (0.0540)  loss_rpn_box_reg: 0.0307 (0.0391)  time: 0.5512  data: 0.0076  max mem: 3590
# Epoch: [0]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.7767 (1.0831)  loss_classifier: 0.3221 (0.6414)  loss_box_reg: 0.3288 (0.3482)  loss_objectness: 0.0267 (0.0544)  loss_rpn_box_reg: 0.0246 (0.0390)  time: 0.5459  data: 0.0079  max mem: 3590
# Epoch: [0] Total time: 0:02:09 (0.5902 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:56  model_time: 0.2829 (0.2829)  evaluator_time: 0.0223 (0.0223)  time: 0.5305  data: 0.2232  max mem: 3590
# Test:  [100/220]  eta: 0:00:31  model_time: 0.2289 (0.2432)  evaluator_time: 0.0083 (0.0100)  time: 0.2645  data: 0.0072  max mem: 3590
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2264 (0.2398)  evaluator_time: 0.0079 (0.0098)  time: 0.2503  data: 0.0079  max mem: 3590
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2257 (0.2396)  evaluator_time: 0.0078 (0.0097)  time: 0.2549  data: 0.0077  max mem: 3590
# Test: Total time: 0:00:57 (0.2602 s / it)
# Averaged stats: model_time: 0.2257 (0.2396)  evaluator_time: 0.0078 (0.0097)
# Accumulating evaluation results...
# DONE (t=0.58s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.017
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.032
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.095
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.173
# Epoch: [1]  [  0/220]  eta: 0:02:51  lr: 0.005000  loss: 1.7110 (1.7110)  loss_classifier: 0.7674 (0.7674)  loss_box_reg: 0.8290 (0.8290)  loss_objectness: 0.0288 (0.0288)  loss_rpn_box_reg: 0.0858 (0.0858)  time: 0.7797  data: 0.1868  max mem: 3590
# Epoch: [1]  [ 10/220]  eta: 0:02:06  lr: 0.005000  loss: 0.5831 (0.7395)  loss_classifier: 0.2388 (0.3222)  loss_box_reg: 0.3005 (0.3696)  loss_objectness: 0.0116 (0.0163)  loss_rpn_box_reg: 0.0264 (0.0313)  time: 0.6028  data: 0.0275  max mem: 3590
# Epoch: [1]  [ 20/220]  eta: 0:01:55  lr: 0.005000  loss: 0.4384 (0.6251)  loss_classifier: 0.1875 (0.2744)  loss_box_reg: 0.2475 (0.3081)  loss_objectness: 0.0135 (0.0195)  loss_rpn_box_reg: 0.0108 (0.0231)  time: 0.5676  data: 0.0100  max mem: 3590
# Epoch: [1]  [ 30/220]  eta: 0:01:48  lr: 0.005000  loss: 0.4455 (0.6487)  loss_classifier: 0.1875 (0.2751)  loss_box_reg: 0.2475 (0.3224)  loss_objectness: 0.0207 (0.0213)  loss_rpn_box_reg: 0.0181 (0.0298)  time: 0.5522  data: 0.0081  max mem: 3590
# Epoch: [1]  [ 40/220]  eta: 0:01:41  lr: 0.005000  loss: 0.6607 (0.6856)  loss_classifier: 0.2733 (0.2946)  loss_box_reg: 0.3250 (0.3318)  loss_objectness: 0.0199 (0.0229)  loss_rpn_box_reg: 0.0259 (0.0363)  time: 0.5518  data: 0.0078  max mem: 3590
# Epoch: [1]  [ 50/220]  eta: 0:01:37  lr: 0.005000  loss: 0.7446 (0.6984)  loss_classifier: 0.2733 (0.2992)  loss_box_reg: 0.3697 (0.3421)  loss_objectness: 0.0185 (0.0224)  loss_rpn_box_reg: 0.0213 (0.0348)  time: 0.5759  data: 0.0085  max mem: 3868
# Epoch: [1]  [ 60/220]  eta: 0:01:31  lr: 0.005000  loss: 0.6058 (0.6818)  loss_classifier: 0.2190 (0.2896)  loss_box_reg: 0.3471 (0.3380)  loss_objectness: 0.0175 (0.0216)  loss_rpn_box_reg: 0.0212 (0.0326)  time: 0.5848  data: 0.0088  max mem: 3868
# Epoch: [1]  [ 70/220]  eta: 0:01:24  lr: 0.005000  loss: 0.5329 (0.6609)  loss_classifier: 0.2015 (0.2810)  loss_box_reg: 0.2747 (0.3295)  loss_objectness: 0.0121 (0.0204)  loss_rpn_box_reg: 0.0121 (0.0300)  time: 0.5455  data: 0.0079  max mem: 3868
# Epoch: [1]  [ 80/220]  eta: 0:01:18  lr: 0.005000  loss: 0.5329 (0.6563)  loss_classifier: 0.2309 (0.2784)  loss_box_reg: 0.2747 (0.3267)  loss_objectness: 0.0118 (0.0204)  loss_rpn_box_reg: 0.0134 (0.0307)  time: 0.5262  data: 0.0075  max mem: 3868
# Epoch: [1]  [ 90/220]  eta: 0:01:13  lr: 0.005000  loss: 0.6381 (0.6501)  loss_classifier: 0.2649 (0.2777)  loss_box_reg: 0.2973 (0.3227)  loss_objectness: 0.0133 (0.0197)  loss_rpn_box_reg: 0.0225 (0.0300)  time: 0.5570  data: 0.0074  max mem: 3868
# Epoch: [1]  [100/220]  eta: 0:01:07  lr: 0.005000  loss: 0.5172 (0.6384)  loss_classifier: 0.2500 (0.2734)  loss_box_reg: 0.2663 (0.3163)  loss_objectness: 0.0097 (0.0198)  loss_rpn_box_reg: 0.0068 (0.0288)  time: 0.5565  data: 0.0073  max mem: 3868
# Epoch: [1]  [110/220]  eta: 0:01:02  lr: 0.005000  loss: 0.5172 (0.6359)  loss_classifier: 0.2303 (0.2699)  loss_box_reg: 0.2612 (0.3145)  loss_objectness: 0.0104 (0.0200)  loss_rpn_box_reg: 0.0081 (0.0314)  time: 0.5670  data: 0.0074  max mem: 3869
# Epoch: [1]  [120/220]  eta: 0:00:56  lr: 0.005000  loss: 0.5187 (0.6249)  loss_classifier: 0.2203 (0.2646)  loss_box_reg: 0.2502 (0.3091)  loss_objectness: 0.0104 (0.0207)  loss_rpn_box_reg: 0.0129 (0.0304)  time: 0.5841  data: 0.0073  max mem: 3869
# Epoch: [1]  [130/220]  eta: 0:00:50  lr: 0.005000  loss: 0.4951 (0.6128)  loss_classifier: 0.1893 (0.2592)  loss_box_reg: 0.2502 (0.3037)  loss_objectness: 0.0096 (0.0201)  loss_rpn_box_reg: 0.0117 (0.0297)  time: 0.5585  data: 0.0075  max mem: 3869
# Epoch: [1]  [140/220]  eta: 0:00:45  lr: 0.005000  loss: 0.4951 (0.6302)  loss_classifier: 0.2010 (0.2558)  loss_box_reg: 0.2600 (0.3028)  loss_objectness: 0.0128 (0.0335)  loss_rpn_box_reg: 0.0145 (0.0381)  time: 0.5678  data: 0.0078  max mem: 3869
# Epoch: [1]  [150/220]  eta: 0:00:39  lr: 0.005000  loss: 0.4356 (0.6244)  loss_classifier: 0.2104 (0.2541)  loss_box_reg: 0.2229 (0.2996)  loss_objectness: 0.0230 (0.0331)  loss_rpn_box_reg: 0.0124 (0.0376)  time: 0.5724  data: 0.0083  max mem: 3869
# Epoch: [1]  [160/220]  eta: 0:00:33  lr: 0.005000  loss: 0.4581 (0.6168)  loss_classifier: 0.1842 (0.2510)  loss_box_reg: 0.2176 (0.2969)  loss_objectness: 0.0204 (0.0320)  loss_rpn_box_reg: 0.0113 (0.0370)  time: 0.5802  data: 0.0085  max mem: 3869
# Epoch: [1]  [170/220]  eta: 0:00:28  lr: 0.005000  loss: 0.5036 (0.6217)  loss_classifier: 0.2222 (0.2522)  loss_box_reg: 0.2815 (0.3004)  loss_objectness: 0.0204 (0.0318)  loss_rpn_box_reg: 0.0116 (0.0373)  time: 0.5794  data: 0.0082  max mem: 3869
# Epoch: [1]  [180/220]  eta: 0:00:22  lr: 0.005000  loss: 0.5190 (0.6177)  loss_classifier: 0.2251 (0.2522)  loss_box_reg: 0.2387 (0.2983)  loss_objectness: 0.0219 (0.0311)  loss_rpn_box_reg: 0.0147 (0.0361)  time: 0.5791  data: 0.0081  max mem: 3869
# Epoch: [1]  [190/220]  eta: 0:00:17  lr: 0.005000  loss: 0.4798 (0.6121)  loss_classifier: 0.1960 (0.2511)  loss_box_reg: 0.2220 (0.2956)  loss_objectness: 0.0113 (0.0303)  loss_rpn_box_reg: 0.0147 (0.0352)  time: 0.5808  data: 0.0077  max mem: 3869
# Epoch: [1]  [200/220]  eta: 0:00:11  lr: 0.005000  loss: 0.5677 (0.6103)  loss_classifier: 0.2354 (0.2513)  loss_box_reg: 0.2115 (0.2952)  loss_objectness: 0.0082 (0.0293)  loss_rpn_box_reg: 0.0139 (0.0345)  time: 0.5904  data: 0.0084  max mem: 3869
# Epoch: [1]  [210/220]  eta: 0:00:05  lr: 0.005000  loss: 0.4498 (0.6095)  loss_classifier: 0.2275 (0.2520)  loss_box_reg: 0.2041 (0.2940)  loss_objectness: 0.0082 (0.0287)  loss_rpn_box_reg: 0.0142 (0.0349)  time: 0.5953  data: 0.0089  max mem: 3869
# Epoch: [1]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.5786 (0.6130)  loss_classifier: 0.2603 (0.2553)  loss_box_reg: 0.2204 (0.2946)  loss_objectness: 0.0111 (0.0285)  loss_rpn_box_reg: 0.0135 (0.0346)  time: 0.5649  data: 0.0077  max mem: 3869
# Epoch: [1] Total time: 0:02:05 (0.5697 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:59  model_time: 0.3243 (0.3243)  evaluator_time: 0.0102 (0.0102)  time: 0.5438  data: 0.2070  max mem: 3869
# Test:  [100/220]  eta: 0:00:31  model_time: 0.2312 (0.2397)  evaluator_time: 0.0085 (0.0091)  time: 0.2747  data: 0.0081  max mem: 3869
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2298 (0.2405)  evaluator_time: 0.0069 (0.0094)  time: 0.2727  data: 0.0073  max mem: 3869
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2113 (0.2395)  evaluator_time: 0.0089 (0.0094)  time: 0.2523  data: 0.0073  max mem: 3869
# Test: Total time: 0:00:57 (0.2598 s / it)
# Averaged stats: model_time: 0.2113 (0.2395)  evaluator_time: 0.0089 (0.0094)
# Accumulating evaluation results...
# DONE (t=0.62s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.066
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.137
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.144
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.090
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.261
# Epoch: [2]  [  0/220]  eta: 0:02:42  lr: 0.005000  loss: 0.5228 (0.5228)  loss_classifier: 0.2414 (0.2414)  loss_box_reg: 0.2204 (0.2204)  loss_objectness: 0.0086 (0.0086)  loss_rpn_box_reg: 0.0523 (0.0523)  time: 0.7402  data: 0.2143  max mem: 3869
# Epoch: [2]  [ 10/220]  eta: 0:02:04  lr: 0.005000  loss: 0.5960 (0.5509)  loss_classifier: 0.2097 (0.2142)  loss_box_reg: 0.3429 (0.2970)  loss_objectness: 0.0067 (0.0100)  loss_rpn_box_reg: 0.0188 (0.0298)  time: 0.5930  data: 0.0254  max mem: 3869
# Epoch: [2]  [ 20/220]  eta: 0:01:53  lr: 0.005000  loss: 0.5884 (0.5633)  loss_classifier: 0.1825 (0.2256)  loss_box_reg: 0.3424 (0.2989)  loss_objectness: 0.0071 (0.0123)  loss_rpn_box_reg: 0.0180 (0.0265)  time: 0.5585  data: 0.0068  max mem: 3869
# Epoch: [2]  [ 30/220]  eta: 0:01:46  lr: 0.005000  loss: 0.4842 (0.5463)  loss_classifier: 0.2259 (0.2293)  loss_box_reg: 0.2162 (0.2792)  loss_objectness: 0.0133 (0.0142)  loss_rpn_box_reg: 0.0139 (0.0236)  time: 0.5465  data: 0.0080  max mem: 3869
# Epoch: [2]  [ 40/220]  eta: 0:01:39  lr: 0.005000  loss: 0.4972 (0.5508)  loss_classifier: 0.2179 (0.2295)  loss_box_reg: 0.2184 (0.2819)  loss_objectness: 0.0145 (0.0154)  loss_rpn_box_reg: 0.0137 (0.0241)  time: 0.5417  data: 0.0082  max mem: 3869
# Epoch: [2]  [ 50/220]  eta: 0:01:35  lr: 0.005000  loss: 0.4972 (0.5465)  loss_classifier: 0.2131 (0.2301)  loss_box_reg: 0.2369 (0.2768)  loss_objectness: 0.0142 (0.0151)  loss_rpn_box_reg: 0.0200 (0.0244)  time: 0.5607  data: 0.0075  max mem: 3869
# Epoch: [2]  [ 60/220]  eta: 0:01:29  lr: 0.005000  loss: 0.4839 (0.5501)  loss_classifier: 0.2205 (0.2325)  loss_box_reg: 0.2444 (0.2771)  loss_objectness: 0.0123 (0.0156)  loss_rpn_box_reg: 0.0139 (0.0249)  time: 0.5692  data: 0.0076  max mem: 3869
# Epoch: [2]  [ 70/220]  eta: 0:01:23  lr: 0.005000  loss: 0.4839 (0.5538)  loss_classifier: 0.2205 (0.2365)  loss_box_reg: 0.2444 (0.2772)  loss_objectness: 0.0079 (0.0153)  loss_rpn_box_reg: 0.0091 (0.0247)  time: 0.5449  data: 0.0079  max mem: 3869
# Epoch: [2]  [ 80/220]  eta: 0:01:19  lr: 0.005000  loss: 0.4551 (0.5555)  loss_classifier: 0.2003 (0.2384)  loss_box_reg: 0.2318 (0.2768)  loss_objectness: 0.0097 (0.0149)  loss_rpn_box_reg: 0.0139 (0.0254)  time: 0.5941  data: 0.0083  max mem: 3869
# Epoch: [2]  [ 90/220]  eta: 0:01:13  lr: 0.005000  loss: 0.4551 (0.5463)  loss_classifier: 0.2027 (0.2375)  loss_box_reg: 0.2000 (0.2703)  loss_objectness: 0.0098 (0.0146)  loss_rpn_box_reg: 0.0105 (0.0239)  time: 0.5892  data: 0.0078  max mem: 3869
# Epoch: [2]  [100/220]  eta: 0:01:08  lr: 0.005000  loss: 0.4235 (0.5391)  loss_classifier: 0.1918 (0.2319)  loss_box_reg: 0.1998 (0.2662)  loss_objectness: 0.0108 (0.0145)  loss_rpn_box_reg: 0.0068 (0.0265)  time: 0.5689  data: 0.0075  max mem: 3869
# Epoch: [2]  [110/220]  eta: 0:01:02  lr: 0.005000  loss: 0.4313 (0.5362)  loss_classifier: 0.1918 (0.2308)  loss_box_reg: 0.2078 (0.2657)  loss_objectness: 0.0073 (0.0139)  loss_rpn_box_reg: 0.0144 (0.0258)  time: 0.5980  data: 0.0078  max mem: 3869
# Epoch: [2]  [120/220]  eta: 0:00:57  lr: 0.005000  loss: 0.4510 (0.5279)  loss_classifier: 0.2032 (0.2270)  loss_box_reg: 0.2142 (0.2618)  loss_objectness: 0.0063 (0.0134)  loss_rpn_box_reg: 0.0144 (0.0257)  time: 0.6106  data: 0.0076  max mem: 3869
# Epoch: [2]  [130/220]  eta: 0:00:51  lr: 0.005000  loss: 0.3970 (0.5178)  loss_classifier: 0.1580 (0.2235)  loss_box_reg: 0.1914 (0.2560)  loss_objectness: 0.0053 (0.0130)  loss_rpn_box_reg: 0.0122 (0.0254)  time: 0.5987  data: 0.0073  max mem: 3869
# Epoch: [2]  [140/220]  eta: 0:00:45  lr: 0.005000  loss: 0.3926 (0.5188)  loss_classifier: 0.1591 (0.2185)  loss_box_reg: 0.1702 (0.2501)  loss_objectness: 0.0095 (0.0178)  loss_rpn_box_reg: 0.0118 (0.0324)  time: 0.5466  data: 0.0075  max mem: 3869
# Epoch: [2]  [150/220]  eta: 0:00:40  lr: 0.005000  loss: 0.3574 (0.5078)  loss_classifier: 0.1591 (0.2143)  loss_box_reg: 0.1447 (0.2440)  loss_objectness: 0.0146 (0.0177)  loss_rpn_box_reg: 0.0118 (0.0317)  time: 0.5641  data: 0.0076  max mem: 3869
# Epoch: [2]  [160/220]  eta: 0:00:34  lr: 0.005000  loss: 0.3860 (0.5093)  loss_classifier: 0.1638 (0.2137)  loss_box_reg: 0.1865 (0.2464)  loss_objectness: 0.0117 (0.0176)  loss_rpn_box_reg: 0.0155 (0.0316)  time: 0.5713  data: 0.0078  max mem: 3869
# Epoch: [2]  [170/220]  eta: 0:00:28  lr: 0.005000  loss: 0.3923 (0.5049)  loss_classifier: 0.1579 (0.2124)  loss_box_reg: 0.2368 (0.2440)  loss_objectness: 0.0085 (0.0173)  loss_rpn_box_reg: 0.0133 (0.0312)  time: 0.5425  data: 0.0076  max mem: 3869
# Epoch: [2]  [180/220]  eta: 0:00:22  lr: 0.005000  loss: 0.3799 (0.5020)  loss_classifier: 0.1584 (0.2118)  loss_box_reg: 0.1600 (0.2413)  loss_objectness: 0.0075 (0.0170)  loss_rpn_box_reg: 0.0106 (0.0318)  time: 0.5637  data: 0.0073  max mem: 3869
# Epoch: [2]  [190/220]  eta: 0:00:17  lr: 0.005000  loss: 0.4450 (0.5082)  loss_classifier: 0.2214 (0.2150)  loss_box_reg: 0.2001 (0.2441)  loss_objectness: 0.0089 (0.0171)  loss_rpn_box_reg: 0.0257 (0.0320)  time: 0.5751  data: 0.0077  max mem: 3869
# Epoch: [2]  [200/220]  eta: 0:00:11  lr: 0.005000  loss: 0.6050 (0.5116)  loss_classifier: 0.2381 (0.2163)  loss_box_reg: 0.3103 (0.2464)  loss_objectness: 0.0112 (0.0169)  loss_rpn_box_reg: 0.0277 (0.0321)  time: 0.5561  data: 0.0077  max mem: 3869
# Epoch: [2]  [210/220]  eta: 0:00:05  lr: 0.005000  loss: 0.4807 (0.5048)  loss_classifier: 0.1946 (0.2135)  loss_box_reg: 0.2160 (0.2430)  loss_objectness: 0.0123 (0.0169)  loss_rpn_box_reg: 0.0206 (0.0313)  time: 0.5440  data: 0.0081  max mem: 3869
# Epoch: [2]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.4138 (0.5038)  loss_classifier: 0.1552 (0.2127)  loss_box_reg: 0.2254 (0.2436)  loss_objectness: 0.0106 (0.0166)  loss_rpn_box_reg: 0.0146 (0.0309)  time: 0.5385  data: 0.0087  max mem: 3869
# Epoch: [2] Total time: 0:02:04 (0.5666 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:55  model_time: 0.2923 (0.2923)  evaluator_time: 0.0159 (0.0159)  time: 0.5262  data: 0.2155  max mem: 3869
# Test:  [100/220]  eta: 0:00:31  model_time: 0.2321 (0.2412)  evaluator_time: 0.0049 (0.0075)  time: 0.2595  data: 0.0080  max mem: 3869
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2263 (0.2411)  evaluator_time: 0.0054 (0.0077)  time: 0.2569  data: 0.0082  max mem: 3869
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2261 (0.2402)  evaluator_time: 0.0050 (0.0076)  time: 0.2461  data: 0.0073  max mem: 3869
# Test: Total time: 0:00:57 (0.2591 s / it)
# Averaged stats: model_time: 0.2261 (0.2402)  evaluator_time: 0.0050 (0.0076)
# Accumulating evaluation results...
# DONE (t=0.42s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.115
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.049
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.096
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.174
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.181
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.306

# %% [markdown]
# At each epoch, an evaluation process is launched to monitor the training. For the last epoch what AP do you get ?

# %% [markdown]
# ### Checkpoints
#
# We may now save the model and the state of optimizers and learning rate schedulers in order to continue training from where we left of. This is known as checkpointing.

# %%
torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'lr_scheduler_state_dict': lr_scheduler.state_dict(),
            }, 'checkpoint.pt')

# %% [markdown]
# We can then re-create model, optimizer and lr_scheduler from scratch and simply load their state from the checkpoint file we have just saved.
#
# In case you have not been able to train your model during the break or have lost your model for some reason we provide you a checkpoint from this link which you can download and upload it to Colab to continue with the lab: [https://drive.google.com/file/d/1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ/view?usp=sharing](https://drive.google.com/file/d/1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ/view?usp=sharing)
#
# We may download it directly to Colab by doing:
#
# ```
# gdown --id 1u-OA-XUGE3JA3czarnFInHLw-QQ22hFQ
# ```

# %%
model = get_detection_model(num_classes)
# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params,
                            lr=0.005,
                            momentum=0.9,
                            weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

checkpoint = torch.load('checkpoint.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
lr_scheduler.load_state_dict(checkpoint['lr_scheduler_state_dict'])
epoch = checkpoint['epoch']

model.eval()
model.train()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=15, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=60, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Exercise 6: Visualize the result on an image
#
# Computer Vision has the great advantage to be visual. Le's check the prediction on a an image.

# %%
from torchvision.transforms.functional import convert_image_dtype

# Batch images
batch_int = torch.stack([img1_int])
batch = convert_image_dtype(batch_int, dtype=torch.float).to(device)

model = model.eval()

# Print images with model prediction
outputs = model(batch)
print(outputs)
# Out:
# [{'boxes': tensor([[191.3784, 213.9927, 280.2482, 251.4216],
#         [270.8130, 180.3071, 437.6235, 276.6364],
#         [270.2291,   5.3385, 440.4399, 277.3130],
#         [300.0168,   1.3479, 427.9470, 328.4692],
#         [428.9918, 234.8638, 499.9006, 274.5449],
#         [245.8085,   8.3240, 487.3215, 265.4313],
#         [285.8304, 109.2048, 435.1930, 278.7835],
#         [196.5838, 212.9758, 275.5949, 257.4971],
#         [238.1250, 215.8428, 244.4433, 228.1503],
#         [267.9829,  82.7619, 436.6755, 279.0941],
#         [268.6748, 180.8580, 444.4743, 267.4149],
#         [191.8987, 221.7196, 277.2064, 251.6487],
#         [211.0287, 228.2299, 277.7337, 251.1899],
#         [274.2420, 197.6874, 417.6805, 278.3164],
#         [186.6966, 200.0584, 277.6661, 259.5903],
#         [257.9862, 106.8003, 443.8497, 282.9889],
#         [250.2951, 154.5227, 452.8402, 272.9220],
#         [430.1862, 236.4828, 500.0000, 273.8047],
#         [195.1799, 211.4295, 272.1029, 259.2662],
#         [277.4286, 169.2501, 477.6973, 269.2296],
#         [189.6143, 184.8827, 281.3752, 264.4959],
#         [165.7210, 213.9616, 308.5045, 255.3476],
#         [194.8195, 214.0581, 258.3665, 239.3128],
#         [173.8039, 217.6331, 274.7547, 240.1265],
#         [266.6745, 168.7275, 500.0000, 271.7831],
#         [277.0311,  61.5279, 424.7441, 286.5240]], device='cuda:0',
#        grad_fn=<StackBackward0>), 'labels': tensor([14, 14,  2,  5, 14,  5,  5,  6,  3, 14,  6,  4, 14,  4,  4,  6,  2,  4,
#          7,  5,  6,  4, 14,  4,  7,  9], device='cuda:0'), 'scores': tensor([0.6939, 0.5685, 0.3802, 0.3682, 0.2453, 0.2183, 0.1854, 0.1646, 0.1619,
#         0.1489, 0.1437, 0.1407, 0.1322, 0.1273, 0.0753, 0.0723, 0.0712, 0.0678,
#         0.0648, 0.0644, 0.0641, 0.0612, 0.0564, 0.0552, 0.0534, 0.0508],
#        device='cuda:0', grad_fn=<IndexBackward0>)}]

# %%
# Select minimum threshold for keeping bbox
score_threshold = .3
# Show boxes
imgs_with_boxes = [
    draw_bounding_boxes(img_int,
                        boxes=output['boxes'][output['scores'] > score_threshold],
                        width=4)
    for img_int, output in zip(batch_int, outputs)
]
show(imgs_with_boxes)

# %% [markdown]
# Play with the score threshold.
#
# Can you select a good trade-off threshold ?
#
# Can you think of a technique to remove the duplicated bounding boxes ?

# %%
# Import the torchvision
from torchvision import ops

# Define a function 'show_filtered_images' that takes in 3 parameters - 'batch_int', 'outputs', and 'score_threshold'
def show_filtered_images(batch_int, outputs, score_threshold):
  # Create a list 'imgs_with_boxes' that contains the result of 'draw_bounding_boxes' for each image in 'batch_int'
  imgs_with_boxes = [
      draw_bounding_boxes(img_int,
                          boxes=output['boxes'][output['scores'] > score_threshold],
                          width=4)
      for img_int, output in zip(batch_int, outputs)
  ]
  # Call the 'show' function to display the images
  show(imgs_with_boxes)

# Define a function 'show_nms_boxes' that takes in 3 parameters - 'batch_int', 'outputs', and 'score_threshold'
def show_nms_boxes(batch_int, outputs, score_threshold):
  # Loop over each image and output in 'batch_int' and 'outputs'
  for img_int, output in zip(batch_int, outputs):
    idxs = output['scores'] > score_threshold
    # Apply the non-maximum suppression
    boxes = torchvision.ops.batched_nms(boxes = output['boxes'][idxs], 
                              scores = output['scores'][idxs], 
                              idxs = output['labels'][idxs], 
                              iou_threshold = 0.6)
    # Convert the 'boxes' tensor to a list
    boxes_idxes = boxes.tolist()
    # Create a list 'imgs_with_boxes' that contains the result of 'draw_bounding_boxes' for each image in 'batch_int'
    imgs_with_boxes = [
        draw_bounding_boxes(img_int,
                          boxes=output['boxes'][boxes_idxes],
                          width=4)
    ]
  show(imgs_with_boxes)

# Set a threshold of 0.5
score_threshold = 0.5

# Call the 'show_filtered_images'
show_filtered_images(batch_int, outputs, score_threshold)

# Call the 'show_nms_boxes"
show_nms_boxes(batch_int, outputs, score_threshold)

# %%
for img_int, output in zip(batch_int, outputs):
  toto = ops.nms(output['boxes'], output['scores'], iou_threshold=0.5)
  print(toto)
# Out:
# tensor([ 0,  1,  2,  4,  8, 12, 20, 22], device='cuda:0')

# %%
for img_int, output in zip(batch_int, outputs):
  print(output['boxes'][toto])
# Out:
# tensor([[191.3784, 213.9927, 280.2482, 251.4216],
#         [270.8130, 180.3071, 437.6235, 276.6364],
#         [270.2291,   5.3385, 440.4399, 277.3130],
#         [428.9918, 234.8638, 499.9006, 274.5449],
#         [238.1250, 215.8428, 244.4433, 228.1503],
#         [211.0287, 228.2299, 277.7337, 251.1899],
#         [189.6143, 184.8827, 281.3752, 264.4959],
#         [194.8195, 214.0581, 258.3665, 239.3128]], device='cuda:0',
#        grad_fn=<IndexBackward0>)

# %% [markdown]
# ## Exercise 7: Create a MVP (Minimum Viable Product)
#
# To cope with the small unbalanced dataset we have, two solutions are available
#
# * Get more data on the internet or at sea, but we don't have time to search and annotate new data. Annotation is a faily time-consuming process. [Make a try](https://www.makesense.ai/)
# * Merge classes to simplify the problem and balance the data.
#
# For example in our case 14 categories is detailed. Indeed we want to be able to separate
#
# * small_vessel -> [boat, motor_sail, zodiac]
# * big_vessel -> [ferry, vessel, fishing_boat]
# * sail_vessel -> [sail, windsurf, kite]
# * human_powered_vessel -> [kayak, surfboard]
# * person
# * other -> [buoy, OFNI]
#
# ```
# TODO
# 1. Modify the dictionnary of annotations.
# 2. Modify the dataLoader class to implement that merging process.
# ```

# %%
# New maritime dictionnary for MVP
new_maritime_dict = {
    0: "small_vessel",
    1: "big_vessel",
    2: "sail_vessel",
    3: "human_powered_vessel",
    4: "person",
    5: "other"
}

# %%
# Create a dictionnary to convert labels
merging_dict = {
    0: 0,
    1: 5,
    2: 2,
    3: 4,
    4: 3,
    5: 0,
    6: 1,
    7: 1,
    8: 0,
    9: 1,
    10: 5,
    11: 2,
    12: 2,
    13: 3
}

# %% [markdown]
# Recreate count of all images to recreate class balance. You can use the function from exercise 1.

# %%
# Get annotations from txt files
def mvp_count_objects(data_path):
  """
  Function reading all txt files from a yolo format and returning number of objects by class

  <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
  <object-class> - integer number of object from 0 to (classes-1)
  <XCenterRelative> <YCenterRelative> - center of the bounding box [0,1]
  <WidthRelative> <HeightRelative> - width and height [0,1]
  """
  classes = []

  ### BEGIN SOLUTION
  return count_objects(data_path)
  ### END SOLUTION

# %%
# apply count and rename classes
### BEGIN SOLUTION
count_df =  mvp_count_objects(data_path)
def mvp_labels(df):
  df = df.rename(merging_dict)
  df = df.groupby(level=0).sum()
  df = df.rename(new_maritime_dict)
  return df
### END SOLUTION
count_df = mvp_labels(count_df)

assert count_df['sail_vessel'] == 170
count_df
# Out:
# small_vessel            592
# big_vessel              234
# sail_vessel             170
# human_powered_vessel    171
# person                  572
# other                   157
# Name: 0, dtype: int64

# %% [markdown]
# Now that we can see that the dataset is more balanced, let's modify the dataloader to modify the class during the loading of the data.

# %%
class VocDataset(torch.utils.data.Dataset):
  def __init__(self, root, transform=None):
    self.root = root
    self.transform = transform
    # load all image files, sorting them to ensure that they are aligned
    self.imgs = list(sorted(Path(root).glob('*.jpg')))
    self.bboxes = list(sorted(Path(root).glob('*.txt')))[:-1] # ignore labels.txt


  def __getitem__(self, idx):

    # get image and bounding boxes paths
    img_path = os.path.join(self.imgs[idx])
    bbox_path = os.path.join(self.bboxes[idx])
    # open image and convert to RGB
    img = Image.open(img_path).convert("RGB")
    # get width and height
    width, height = img.size
    # get bounding boxes
    bbox_df = pd.read_csv(bbox_path, sep=' ', header=None)
        
    # get bounding box coordinates
    # YOLO format reminder :
    # <object-class> <XCenterRelative> <YCenterRelative> <WidthRelative> <HeightRelative>
    boxes = []
    for index, row in bbox_df.iterrows():
      xmin = (row[1] - (row[3] / 2)) * width
      xmax = (row[1] + (row[3] / 2)) * width
      ymin = (row[2] - (row[4] / 2)) * height
      ymax = (row[2] + (row[4] / 2)) * height
      if xmin < xmax and ymin < ymax:
        boxes.append([xmin, ymin, xmax, ymax])

    # convert everything into a torch.Tensor
    boxes = torch.as_tensor(boxes, dtype=torch.float32)

    ## BEGIN SOLUTION

    # replace labels with new dict
    labels = [merging_dict.get(x) for x in bbox_df[0]]
    # replace label 0 by 6
    labels = [int(x) if x != 0 else 6 for x in labels]
    # convert labels to a torch.Tensor
    labels =  torch.as_tensor(labels, dtype=torch.int64)

    ### END SOLUTION

    # get image od
    image_id = torch.tensor([idx])
    # compute area of the bounding boxes
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    # suppose all instances are not crowd
    iscrowd = torch.zeros((len(bbox_df),), dtype=torch.int64)

    # populate target dictionnary
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = image_id
    target["area"] = area
    target["iscrowd"] = iscrowd

    # image transformation
    if self.transform is not None:
      img, target = self.transform(img, target)

    return img, target


  def __len__(self):
    return len(self.imgs)

# %%
dataset = VocDataset(data_path)
assert torch.equal(dataset[0][1]['labels'], torch.tensor([6,1]))
dataset[0]
# Out:
# (<PIL.Image.Image image mode=RGB size=500x333 at 0x7F34F3C42790>,
#  {'boxes': tensor([[274.0000,  10.9998, 437.0000, 278.9999],
#           [187.3420, 214.0001, 281.0000, 252.0001]]),
#   'labels': tensor([6, 1]),
#   'image_id': tensor([0]),
#   'area': tensor([43684.0117,  3559.0000]),
#   'iscrowd': tensor([0, 0])})

# %% [markdown]
# Labels [5, 6] have been transformed to [6, 1]

# %% [markdown]
# ## Exercise 8: Retrain the model
#
# Train the model with the new dataset.
#
# Take code already written in exercise 5 and modify it to train the model again.

# %%
### BEGIN SOLUTION
from engine import train_one_epoch, evaluate

### BEGIN SOLUTION

# use our dataset and defined transformations
dataset = VocDataset(data_path, get_transform(train=True))
dataset_test = VocDataset(data_path, get_transform(train=False))

# split the dataset in train and test set with torch.utils.data.Subset
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset,indices[:int(len(indices)*0.8)] )
dataset_test = torch.utils.data.Subset(dataset,indices[int(len(indices)*0.8):] )

from torch.utils.data import DataLoader
# define training and validation data loaders
data_loader = DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn,
 )# use a batch_size of 4, 2 workers and the shuffle option

data_loader_test = DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=2,
    collate_fn=utils.collate_fn,
 )  # use a batch_size of 2, 2 workers and disable the shuffle option

### END SOLUTION
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has 7 classes but bg class is set to 0
num_classes = 7

### BEGIN SOLUTION

# get the model using our helper function
model = get_detection_model()
model = model.to(device)
# move model to the right device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# construct an optimizer SGD with lr=0.005, momentum=0.9 and weight_decay=0.0005
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.SGD(model.parameters(), lr=0.005, weight_decay=0.0005)
optimizer = torch.optim.SGD(params, lr = 0.005, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

### END SOLUTION
# let's train it for 3 epochs
num_epochs = 3

### BEGIN SOLUTION

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, 10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

### END SOLUTION
# Out:
# Epoch: [0]  [  0/220]  eta: 0:03:33  lr: 0.000028  loss: 2.8923 (2.8923)  loss_classifier: 2.7441 (2.7441)  loss_box_reg: 0.1295 (0.1295)  loss_objectness: 0.0112 (0.0112)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 0.9702  data: 0.2487  max mem: 3869
# Epoch: [0]  [ 10/220]  eta: 0:02:14  lr: 0.000256  loss: 2.8923 (2.9715)  loss_classifier: 2.6699 (2.7067)  loss_box_reg: 0.2057 (0.2272)  loss_objectness: 0.0112 (0.0183)  loss_rpn_box_reg: 0.0108 (0.0192)  time: 0.6393  data: 0.0284  max mem: 4431
# Epoch: [0]  [ 20/220]  eta: 0:02:02  lr: 0.000484  loss: 2.8196 (2.8158)  loss_classifier: 2.4729 (2.4552)  loss_box_reg: 0.2572 (0.3159)  loss_objectness: 0.0143 (0.0213)  loss_rpn_box_reg: 0.0147 (0.0234)  time: 0.5920  data: 0.0077  max mem: 4431
# Epoch: [0]  [ 30/220]  eta: 0:01:53  lr: 0.000712  loss: 2.0955 (2.4427)  loss_classifier: 1.7309 (2.0808)  loss_box_reg: 0.2913 (0.3094)  loss_objectness: 0.0156 (0.0285)  loss_rpn_box_reg: 0.0196 (0.0240)  time: 0.5772  data: 0.0086  max mem: 4431
# Epoch: [0]  [ 40/220]  eta: 0:01:46  lr: 0.000940  loss: 1.3727 (2.1433)  loss_classifier: 0.9000 (1.7580)  loss_box_reg: 0.2726 (0.3256)  loss_objectness: 0.0160 (0.0356)  loss_rpn_box_reg: 0.0199 (0.0241)  time: 0.5764  data: 0.0079  max mem: 4431
# Epoch: [0]  [ 50/220]  eta: 0:01:39  lr: 0.001168  loss: 0.9969 (1.9243)  loss_classifier: 0.6383 (1.5274)  loss_box_reg: 0.3198 (0.3392)  loss_objectness: 0.0108 (0.0313)  loss_rpn_box_reg: 0.0182 (0.0263)  time: 0.5677  data: 0.0075  max mem: 4431
# Epoch: [0]  [ 60/220]  eta: 0:01:32  lr: 0.001396  loss: 0.7793 (1.7450)  loss_classifier: 0.4795 (1.3523)  loss_box_reg: 0.3120 (0.3385)  loss_objectness: 0.0108 (0.0282)  loss_rpn_box_reg: 0.0128 (0.0260)  time: 0.5544  data: 0.0071  max mem: 4431
# Epoch: [0]  [ 70/220]  eta: 0:01:27  lr: 0.001624  loss: 0.7585 (1.6039)  loss_classifier: 0.3953 (1.2180)  loss_box_reg: 0.2787 (0.3307)  loss_objectness: 0.0209 (0.0291)  loss_rpn_box_reg: 0.0176 (0.0261)  time: 0.5629  data: 0.0073  max mem: 4431
# Epoch: [0]  [ 80/220]  eta: 0:01:20  lr: 0.001852  loss: 0.6778 (1.5001)  loss_classifier: 0.3953 (1.1189)  loss_box_reg: 0.2569 (0.3300)  loss_objectness: 0.0195 (0.0271)  loss_rpn_box_reg: 0.0124 (0.0242)  time: 0.5670  data: 0.0077  max mem: 4431
# Epoch: [0]  [ 90/220]  eta: 0:01:15  lr: 0.002081  loss: 0.7015 (1.4351)  loss_classifier: 0.3955 (1.0465)  loss_box_reg: 0.3035 (0.3363)  loss_objectness: 0.0086 (0.0271)  loss_rpn_box_reg: 0.0105 (0.0251)  time: 0.5945  data: 0.0076  max mem: 4488
# Epoch: [0]  [100/220]  eta: 0:01:09  lr: 0.002309  loss: 0.6862 (1.3729)  loss_classifier: 0.3435 (0.9849)  loss_box_reg: 0.2915 (0.3345)  loss_objectness: 0.0086 (0.0279)  loss_rpn_box_reg: 0.0185 (0.0255)  time: 0.5953  data: 0.0073  max mem: 4488
# Epoch: [0]  [110/220]  eta: 0:01:03  lr: 0.002537  loss: 0.6557 (1.3861)  loss_classifier: 0.3355 (0.9376)  loss_box_reg: 0.3045 (0.3416)  loss_objectness: 0.0209 (0.0650)  loss_rpn_box_reg: 0.0276 (0.0419)  time: 0.5475  data: 0.0073  max mem: 4488
# Epoch: [0]  [120/220]  eta: 0:00:57  lr: 0.002765  loss: 0.7787 (1.3356)  loss_classifier: 0.3460 (0.8891)  loss_box_reg: 0.3060 (0.3389)  loss_objectness: 0.0260 (0.0665)  loss_rpn_box_reg: 0.0236 (0.0410)  time: 0.5398  data: 0.0073  max mem: 4488
# Epoch: [0]  [130/220]  eta: 0:00:51  lr: 0.002993  loss: 0.5456 (1.2713)  loss_classifier: 0.2898 (0.8403)  loss_box_reg: 0.2374 (0.3300)  loss_objectness: 0.0215 (0.0627)  loss_rpn_box_reg: 0.0069 (0.0384)  time: 0.5470  data: 0.0074  max mem: 4488
# Epoch: [0]  [140/220]  eta: 0:00:45  lr: 0.003221  loss: 0.5784 (1.2386)  loss_classifier: 0.2648 (0.8067)  loss_box_reg: 0.2622 (0.3328)  loss_objectness: 0.0160 (0.0617)  loss_rpn_box_reg: 0.0084 (0.0374)  time: 0.5543  data: 0.0075  max mem: 4488
# Epoch: [0]  [150/220]  eta: 0:00:39  lr: 0.003449  loss: 0.7818 (1.2066)  loss_classifier: 0.3135 (0.7761)  loss_box_reg: 0.2906 (0.3340)  loss_objectness: 0.0179 (0.0588)  loss_rpn_box_reg: 0.0261 (0.0377)  time: 0.5474  data: 0.0073  max mem: 4488
# Epoch: [0]  [160/220]  eta: 0:00:34  lr: 0.003677  loss: 0.6044 (1.1738)  loss_classifier: 0.2808 (0.7472)  loss_box_reg: 0.2631 (0.3331)  loss_objectness: 0.0147 (0.0565)  loss_rpn_box_reg: 0.0162 (0.0370)  time: 0.5416  data: 0.0075  max mem: 4488
# Epoch: [0]  [170/220]  eta: 0:00:28  lr: 0.003905  loss: 0.5232 (1.1388)  loss_classifier: 0.2250 (0.7183)  loss_box_reg: 0.2453 (0.3301)  loss_objectness: 0.0120 (0.0540)  loss_rpn_box_reg: 0.0114 (0.0363)  time: 0.5631  data: 0.0076  max mem: 4488
# Epoch: [0]  [180/220]  eta: 0:00:22  lr: 0.004133  loss: 0.5710 (1.1275)  loss_classifier: 0.2360 (0.6996)  loss_box_reg: 0.3038 (0.3329)  loss_objectness: 0.0148 (0.0552)  loss_rpn_box_reg: 0.0114 (0.0397)  time: 0.5733  data: 0.0073  max mem: 4488
# Epoch: [0]  [190/220]  eta: 0:00:17  lr: 0.004361  loss: 0.5895 (1.0966)  loss_classifier: 0.2505 (0.6742)  loss_box_reg: 0.2798 (0.3287)  loss_objectness: 0.0322 (0.0551)  loss_rpn_box_reg: 0.0111 (0.0387)  time: 0.5727  data: 0.0075  max mem: 4488
# Epoch: [0]  [200/220]  eta: 0:00:11  lr: 0.004589  loss: 0.6197 (1.0864)  loss_classifier: 0.2505 (0.6599)  loss_box_reg: 0.2829 (0.3329)  loss_objectness: 0.0467 (0.0547)  loss_rpn_box_reg: 0.0209 (0.0390)  time: 0.5624  data: 0.0075  max mem: 4488
# Epoch: [0]  [210/220]  eta: 0:00:05  lr: 0.004818  loss: 0.8532 (1.0733)  loss_classifier: 0.3521 (0.6453)  loss_box_reg: 0.4279 (0.3355)  loss_objectness: 0.0296 (0.0537)  loss_rpn_box_reg: 0.0298 (0.0388)  time: 0.5535  data: 0.0073  max mem: 4488
# Epoch: [0]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.7182 (1.0625)  loss_classifier: 0.2874 (0.6323)  loss_box_reg: 0.3289 (0.3372)  loss_objectness: 0.0254 (0.0544)  loss_rpn_box_reg: 0.0241 (0.0387)  time: 0.5477  data: 0.0070  max mem: 4488
# Epoch: [0] Total time: 0:02:04 (0.5666 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:54  model_time: 0.2518 (0.2518)  evaluator_time: 0.0225 (0.0225)  time: 0.5197  data: 0.2433  max mem: 4488
# Test:  [100/220]  eta: 0:00:31  model_time: 0.2287 (0.2433)  evaluator_time: 0.0102 (0.0121)  time: 0.2711  data: 0.0078  max mem: 4488
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2275 (0.2397)  evaluator_time: 0.0062 (0.0105)  time: 0.2479  data: 0.0073  max mem: 4488
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2260 (0.2395)  evaluator_time: 0.0086 (0.0104)  time: 0.2538  data: 0.0068  max mem: 4488
# Test: Total time: 0:00:57 (0.2607 s / it)
# Averaged stats: model_time: 0.2260 (0.2395)  evaluator_time: 0.0086 (0.0104)
# Accumulating evaluation results...
# DONE (t=0.55s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.049
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.180
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.136
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.257
# Epoch: [1]  [  0/220]  eta: 0:02:57  lr: 0.005000  loss: 1.5333 (1.5333)  loss_classifier: 0.5940 (0.5940)  loss_box_reg: 0.8049 (0.8049)  loss_objectness: 0.0420 (0.0420)  loss_rpn_box_reg: 0.0923 (0.0923)  time: 0.8047  data: 0.2143  max mem: 4488
# Epoch: [1]  [ 10/220]  eta: 0:02:05  lr: 0.005000  loss: 0.5269 (0.6773)  loss_classifier: 0.2472 (0.2791)  loss_box_reg: 0.2676 (0.3478)  loss_objectness: 0.0161 (0.0181)  loss_rpn_box_reg: 0.0270 (0.0323)  time: 0.5994  data: 0.0278  max mem: 4488
# Epoch: [1]  [ 20/220]  eta: 0:01:55  lr: 0.005000  loss: 0.4301 (0.5788)  loss_classifier: 0.1789 (0.2412)  loss_box_reg: 0.2431 (0.2948)  loss_objectness: 0.0124 (0.0191)  loss_rpn_box_reg: 0.0114 (0.0237)  time: 0.5657  data: 0.0088  max mem: 4488
# Epoch: [1]  [ 30/220]  eta: 0:01:48  lr: 0.005000  loss: 0.4551 (0.6109)  loss_classifier: 0.1789 (0.2480)  loss_box_reg: 0.2431 (0.3118)  loss_objectness: 0.0124 (0.0209)  loss_rpn_box_reg: 0.0190 (0.0303)  time: 0.5538  data: 0.0079  max mem: 4488
# Epoch: [1]  [ 40/220]  eta: 0:01:41  lr: 0.005000  loss: 0.6324 (0.6458)  loss_classifier: 0.2585 (0.2662)  loss_box_reg: 0.3464 (0.3205)  loss_objectness: 0.0202 (0.0226)  loss_rpn_box_reg: 0.0273 (0.0366)  time: 0.5530  data: 0.0077  max mem: 4488
# Epoch: [1]  [ 50/220]  eta: 0:01:37  lr: 0.005000  loss: 0.6505 (0.6555)  loss_classifier: 0.2622 (0.2698)  loss_box_reg: 0.3464 (0.3293)  loss_objectness: 0.0178 (0.0213)  loss_rpn_box_reg: 0.0220 (0.0350)  time: 0.5734  data: 0.0078  max mem: 4766
# Epoch: [1]  [ 60/220]  eta: 0:01:31  lr: 0.005000  loss: 0.6030 (0.6402)  loss_classifier: 0.2130 (0.2614)  loss_box_reg: 0.3254 (0.3251)  loss_objectness: 0.0137 (0.0209)  loss_rpn_box_reg: 0.0214 (0.0329)  time: 0.5807  data: 0.0075  max mem: 4766
# Epoch: [1]  [ 70/220]  eta: 0:01:24  lr: 0.005000  loss: 0.4862 (0.6188)  loss_classifier: 0.1975 (0.2518)  loss_box_reg: 0.2544 (0.3166)  loss_objectness: 0.0141 (0.0201)  loss_rpn_box_reg: 0.0127 (0.0304)  time: 0.5452  data: 0.0075  max mem: 4766
# Epoch: [1]  [ 80/220]  eta: 0:01:18  lr: 0.005000  loss: 0.4862 (0.6138)  loss_classifier: 0.1975 (0.2488)  loss_box_reg: 0.2544 (0.3141)  loss_objectness: 0.0141 (0.0200)  loss_rpn_box_reg: 0.0144 (0.0309)  time: 0.5265  data: 0.0076  max mem: 4766
# Epoch: [1]  [ 90/220]  eta: 0:01:13  lr: 0.005000  loss: 0.5889 (0.6016)  loss_classifier: 0.2354 (0.2445)  loss_box_reg: 0.2644 (0.3076)  loss_objectness: 0.0143 (0.0193)  loss_rpn_box_reg: 0.0226 (0.0302)  time: 0.5577  data: 0.0076  max mem: 4766
# Epoch: [1]  [100/220]  eta: 0:01:07  lr: 0.005000  loss: 0.4234 (0.5915)  loss_classifier: 0.1850 (0.2410)  loss_box_reg: 0.2382 (0.3017)  loss_objectness: 0.0137 (0.0198)  loss_rpn_box_reg: 0.0079 (0.0290)  time: 0.5576  data: 0.0076  max mem: 4766
# Epoch: [1]  [110/220]  eta: 0:01:01  lr: 0.005000  loss: 0.4807 (0.5910)  loss_classifier: 0.1996 (0.2396)  loss_box_reg: 0.2533 (0.3006)  loss_objectness: 0.0070 (0.0194)  loss_rpn_box_reg: 0.0081 (0.0315)  time: 0.5678  data: 0.0082  max mem: 4767
# Epoch: [1]  [120/220]  eta: 0:00:56  lr: 0.005000  loss: 0.4974 (0.5814)  loss_classifier: 0.2137 (0.2354)  loss_box_reg: 0.2437 (0.2952)  loss_objectness: 0.0090 (0.0202)  loss_rpn_box_reg: 0.0126 (0.0305)  time: 0.5857  data: 0.0084  max mem: 4767
# Epoch: [1]  [130/220]  eta: 0:00:50  lr: 0.005000  loss: 0.4316 (0.5703)  loss_classifier: 0.1667 (0.2307)  loss_box_reg: 0.2437 (0.2902)  loss_objectness: 0.0124 (0.0197)  loss_rpn_box_reg: 0.0126 (0.0298)  time: 0.5598  data: 0.0079  max mem: 4767
# Epoch: [1]  [140/220]  eta: 0:00:45  lr: 0.005000  loss: 0.4285 (0.5887)  loss_classifier: 0.1649 (0.2280)  loss_box_reg: 0.2441 (0.2894)  loss_objectness: 0.0124 (0.0332)  loss_rpn_box_reg: 0.0152 (0.0382)  time: 0.5672  data: 0.0075  max mem: 4767
# Epoch: [1]  [150/220]  eta: 0:00:39  lr: 0.005000  loss: 0.3879 (0.5805)  loss_classifier: 0.1650 (0.2251)  loss_box_reg: 0.2161 (0.2855)  loss_objectness: 0.0170 (0.0324)  loss_rpn_box_reg: 0.0131 (0.0375)  time: 0.5711  data: 0.0075  max mem: 4767
# Epoch: [1]  [160/220]  eta: 0:00:33  lr: 0.005000  loss: 0.3847 (0.5731)  loss_classifier: 0.1550 (0.2223)  loss_box_reg: 0.2161 (0.2824)  loss_objectness: 0.0097 (0.0315)  loss_rpn_box_reg: 0.0121 (0.0369)  time: 0.5795  data: 0.0074  max mem: 4767
# Epoch: [1]  [170/220]  eta: 0:00:28  lr: 0.005000  loss: 0.4503 (0.5765)  loss_classifier: 0.1639 (0.2229)  loss_box_reg: 0.2742 (0.2850)  loss_objectness: 0.0174 (0.0313)  loss_rpn_box_reg: 0.0123 (0.0373)  time: 0.5794  data: 0.0073  max mem: 4767
# Epoch: [1]  [180/220]  eta: 0:00:22  lr: 0.005000  loss: 0.4503 (0.5735)  loss_classifier: 0.1899 (0.2243)  loss_box_reg: 0.2143 (0.2825)  loss_objectness: 0.0170 (0.0306)  loss_rpn_box_reg: 0.0146 (0.0361)  time: 0.5794  data: 0.0077  max mem: 4767
# Epoch: [1]  [190/220]  eta: 0:00:17  lr: 0.005000  loss: 0.4308 (0.5668)  loss_classifier: 0.1877 (0.2225)  loss_box_reg: 0.1903 (0.2793)  loss_objectness: 0.0164 (0.0298)  loss_rpn_box_reg: 0.0146 (0.0352)  time: 0.5824  data: 0.0083  max mem: 4767
# Epoch: [1]  [200/220]  eta: 0:00:11  lr: 0.005000  loss: 0.4308 (0.5636)  loss_classifier: 0.1877 (0.2222)  loss_box_reg: 0.1903 (0.2781)  loss_objectness: 0.0086 (0.0287)  loss_rpn_box_reg: 0.0139 (0.0345)  time: 0.5884  data: 0.0080  max mem: 4767
# Epoch: [1]  [210/220]  eta: 0:00:05  lr: 0.005000  loss: 0.4381 (0.5630)  loss_classifier: 0.1742 (0.2228)  loss_box_reg: 0.2065 (0.2770)  loss_objectness: 0.0095 (0.0283)  loss_rpn_box_reg: 0.0143 (0.0349)  time: 0.5920  data: 0.0078  max mem: 4767
# Epoch: [1]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.4825 (0.5649)  loss_classifier: 0.1956 (0.2247)  loss_box_reg: 0.2065 (0.2771)  loss_objectness: 0.0132 (0.0284)  loss_rpn_box_reg: 0.0144 (0.0347)  time: 0.5650  data: 0.0074  max mem: 4767
# Epoch: [1] Total time: 0:02:05 (0.5694 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:52  model_time: 0.2962 (0.2962)  evaluator_time: 0.0079 (0.0079)  time: 0.5112  data: 0.2050  max mem: 4767
# Test:  [100/220]  eta: 0:00:31  model_time: 0.2300 (0.2398)  evaluator_time: 0.0083 (0.0089)  time: 0.2723  data: 0.0070  max mem: 4767
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2274 (0.2404)  evaluator_time: 0.0079 (0.0090)  time: 0.2734  data: 0.0074  max mem: 4767
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2121 (0.2395)  evaluator_time: 0.0083 (0.0090)  time: 0.2525  data: 0.0067  max mem: 4767
# Test: Total time: 0:00:56 (0.2590 s / it)
# Averaged stats: model_time: 0.2121 (0.2395)  evaluator_time: 0.0083 (0.0090)
# Accumulating evaluation results...
# DONE (t=0.54s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.183
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.318
# Epoch: [2]  [  0/220]  eta: 0:02:48  lr: 0.005000  loss: 0.5235 (0.5235)  loss_classifier: 0.2202 (0.2202)  loss_box_reg: 0.2329 (0.2329)  loss_objectness: 0.0166 (0.0166)  loss_rpn_box_reg: 0.0539 (0.0539)  time: 0.7667  data: 0.2387  max mem: 4767
# Epoch: [2]  [ 10/220]  eta: 0:02:06  lr: 0.005000  loss: 0.5808 (0.5309)  loss_classifier: 0.2202 (0.1902)  loss_box_reg: 0.3024 (0.2956)  loss_objectness: 0.0148 (0.0154)  loss_rpn_box_reg: 0.0195 (0.0297)  time: 0.6002  data: 0.0302  max mem: 4767
# Epoch: [2]  [ 20/220]  eta: 0:01:54  lr: 0.005000  loss: 0.5473 (0.5287)  loss_classifier: 0.1749 (0.2005)  loss_box_reg: 0.3024 (0.2881)  loss_objectness: 0.0105 (0.0139)  loss_rpn_box_reg: 0.0177 (0.0262)  time: 0.5620  data: 0.0086  max mem: 4767
# Epoch: [2]  [ 30/220]  eta: 0:01:47  lr: 0.005000  loss: 0.5087 (0.5114)  loss_classifier: 0.2109 (0.2068)  loss_box_reg: 0.2188 (0.2668)  loss_objectness: 0.0083 (0.0144)  loss_rpn_box_reg: 0.0141 (0.0233)  time: 0.5479  data: 0.0083  max mem: 4767
# Epoch: [2]  [ 40/220]  eta: 0:01:40  lr: 0.005000  loss: 0.4921 (0.5093)  loss_classifier: 0.1875 (0.2043)  loss_box_reg: 0.2188 (0.2662)  loss_objectness: 0.0124 (0.0149)  loss_rpn_box_reg: 0.0141 (0.0239)  time: 0.5431  data: 0.0081  max mem: 4767
# Epoch: [2]  [ 50/220]  eta: 0:01:36  lr: 0.005000  loss: 0.4572 (0.4994)  loss_classifier: 0.1872 (0.2029)  loss_box_reg: 0.2040 (0.2572)  loss_objectness: 0.0138 (0.0149)  loss_rpn_box_reg: 0.0198 (0.0244)  time: 0.5622  data: 0.0081  max mem: 4767
# Epoch: [2]  [ 60/220]  eta: 0:01:29  lr: 0.005000  loss: 0.4398 (0.4999)  loss_classifier: 0.1887 (0.2029)  loss_box_reg: 0.2209 (0.2570)  loss_objectness: 0.0079 (0.0148)  loss_rpn_box_reg: 0.0125 (0.0251)  time: 0.5706  data: 0.0084  max mem: 4767
# Epoch: [2]  [ 70/220]  eta: 0:01:23  lr: 0.005000  loss: 0.4158 (0.4985)  loss_classifier: 0.1814 (0.2031)  loss_box_reg: 0.2206 (0.2556)  loss_objectness: 0.0079 (0.0149)  loss_rpn_box_reg: 0.0099 (0.0249)  time: 0.5460  data: 0.0082  max mem: 4767
# Epoch: [2]  [ 80/220]  eta: 0:01:19  lr: 0.005000  loss: 0.3919 (0.4966)  loss_classifier: 0.2083 (0.2048)  loss_box_reg: 0.2163 (0.2524)  loss_objectness: 0.0081 (0.0140)  loss_rpn_box_reg: 0.0131 (0.0255)  time: 0.5948  data: 0.0082  max mem: 4767
# Epoch: [2]  [ 90/220]  eta: 0:01:13  lr: 0.005000  loss: 0.3586 (0.4829)  loss_classifier: 0.1708 (0.2008)  loss_box_reg: 0.1860 (0.2445)  loss_objectness: 0.0081 (0.0136)  loss_rpn_box_reg: 0.0107 (0.0241)  time: 0.5897  data: 0.0078  max mem: 4767
# Epoch: [2]  [100/220]  eta: 0:01:08  lr: 0.005000  loss: 0.3273 (0.4769)  loss_classifier: 0.1537 (0.1956)  loss_box_reg: 0.1626 (0.2415)  loss_objectness: 0.0086 (0.0132)  loss_rpn_box_reg: 0.0070 (0.0266)  time: 0.5693  data: 0.0079  max mem: 4767
# Epoch: [2]  [110/220]  eta: 0:01:02  lr: 0.005000  loss: 0.3928 (0.4730)  loss_classifier: 0.1498 (0.1935)  loss_box_reg: 0.2112 (0.2411)  loss_objectness: 0.0057 (0.0125)  loss_rpn_box_reg: 0.0151 (0.0259)  time: 0.5986  data: 0.0077  max mem: 4767
# Epoch: [2]  [120/220]  eta: 0:00:57  lr: 0.005000  loss: 0.3928 (0.4654)  loss_classifier: 0.1498 (0.1902)  loss_box_reg: 0.2118 (0.2368)  loss_objectness: 0.0074 (0.0125)  loss_rpn_box_reg: 0.0151 (0.0258)  time: 0.6110  data: 0.0071  max mem: 4767
# Epoch: [2]  [130/220]  eta: 0:00:51  lr: 0.005000  loss: 0.3396 (0.4568)  loss_classifier: 0.1436 (0.1875)  loss_box_reg: 0.1592 (0.2319)  loss_objectness: 0.0061 (0.0120)  loss_rpn_box_reg: 0.0128 (0.0255)  time: 0.5993  data: 0.0071  max mem: 4767
# Epoch: [2]  [140/220]  eta: 0:00:45  lr: 0.005000  loss: 0.3202 (0.4583)  loss_classifier: 0.1373 (0.1828)  loss_box_reg: 0.1498 (0.2258)  loss_objectness: 0.0051 (0.0168)  loss_rpn_box_reg: 0.0113 (0.0329)  time: 0.5467  data: 0.0072  max mem: 4767
# Epoch: [2]  [150/220]  eta: 0:00:40  lr: 0.005000  loss: 0.2810 (0.4483)  loss_classifier: 0.1113 (0.1792)  loss_box_reg: 0.1291 (0.2202)  loss_objectness: 0.0118 (0.0168)  loss_rpn_box_reg: 0.0113 (0.0321)  time: 0.5636  data: 0.0073  max mem: 4767
# Epoch: [2]  [160/220]  eta: 0:00:34  lr: 0.005000  loss: 0.3377 (0.4506)  loss_classifier: 0.1285 (0.1792)  loss_box_reg: 0.1896 (0.2229)  loss_objectness: 0.0091 (0.0165)  loss_rpn_box_reg: 0.0152 (0.0319)  time: 0.5715  data: 0.0073  max mem: 4767
# Epoch: [2]  [170/220]  eta: 0:00:28  lr: 0.005000  loss: 0.3371 (0.4474)  loss_classifier: 0.1285 (0.1786)  loss_box_reg: 0.2042 (0.2213)  loss_objectness: 0.0086 (0.0161)  loss_rpn_box_reg: 0.0138 (0.0315)  time: 0.5425  data: 0.0074  max mem: 4767
# Epoch: [2]  [180/220]  eta: 0:00:22  lr: 0.005000  loss: 0.3162 (0.4453)  loss_classifier: 0.1389 (0.1782)  loss_box_reg: 0.1483 (0.2192)  loss_objectness: 0.0098 (0.0161)  loss_rpn_box_reg: 0.0114 (0.0318)  time: 0.5642  data: 0.0080  max mem: 4767
# Epoch: [2]  [190/220]  eta: 0:00:17  lr: 0.005000  loss: 0.3607 (0.4508)  loss_classifier: 0.1537 (0.1810)  loss_box_reg: 0.1807 (0.2216)  loss_objectness: 0.0136 (0.0163)  loss_rpn_box_reg: 0.0250 (0.0319)  time: 0.5757  data: 0.0079  max mem: 4767
# Epoch: [2]  [200/220]  eta: 0:00:11  lr: 0.005000  loss: 0.5564 (0.4555)  loss_classifier: 0.2217 (0.1827)  loss_box_reg: 0.2854 (0.2243)  loss_objectness: 0.0159 (0.0165)  loss_rpn_box_reg: 0.0277 (0.0320)  time: 0.5562  data: 0.0076  max mem: 4767
# Epoch: [2]  [210/220]  eta: 0:00:05  lr: 0.005000  loss: 0.4722 (0.4507)  loss_classifier: 0.1893 (0.1810)  loss_box_reg: 0.2332 (0.2220)  loss_objectness: 0.0128 (0.0164)  loss_rpn_box_reg: 0.0198 (0.0312)  time: 0.5438  data: 0.0077  max mem: 4767
# Epoch: [2]  [219/220]  eta: 0:00:00  lr: 0.005000  loss: 0.4540 (0.4485)  loss_classifier: 0.1512 (0.1796)  loss_box_reg: 0.2460 (0.2221)  loss_objectness: 0.0054 (0.0159)  loss_rpn_box_reg: 0.0147 (0.0309)  time: 0.5387  data: 0.0075  max mem: 4767
# Epoch: [2] Total time: 0:02:04 (0.5675 s / it)
# creating index...
# index created!
# Test:  [  0/220]  eta: 0:01:51  model_time: 0.2807 (0.2807)  evaluator_time: 0.0173 (0.0173)  time: 0.5071  data: 0.2067  max mem: 4767
# Test:  [100/220]  eta: 0:00:30  model_time: 0.2303 (0.2406)  evaluator_time: 0.0036 (0.0063)  time: 0.2575  data: 0.0076  max mem: 4767
# Test:  [200/220]  eta: 0:00:05  model_time: 0.2276 (0.2410)  evaluator_time: 0.0047 (0.0061)  time: 0.2559  data: 0.0069  max mem: 4767
# Test:  [219/220]  eta: 0:00:00  model_time: 0.2267 (0.2402)  evaluator_time: 0.0048 (0.0061)  time: 0.2454  data: 0.0071  max mem: 4767
# Test: Total time: 0:00:56 (0.2565 s / it)
# Averaged stats: model_time: 0.2267 (0.2402)  evaluator_time: 0.0048 (0.0061)
# Accumulating evaluation results...
# DONE (t=0.37s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.248
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.095
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.147
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.159
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.249
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.293
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.342

# %% [markdown]
# Can you explain the new AP score of the model on this simpler dataset ?

# %% [markdown]
# ## Exercise 9: Test on new images
#
# Take images on Google or where you want to apply the model on it, in a maritime context or in completely different one.
#
# Try to answer those questions with empirical test:
#
# 1. Is the model good on all situation ?
# 2. Can you see a difference on small/medium/large objects ?
# 3. Can you isolate difficult images for it ?
# 4. Easy ones ?
# 5. Do you have good accuracy on different weather ?
# 6. Considering your answers how could you improve the dataset to improve the training of the model ?

# %%
# Download the image file from the URL and save it as 'image.jpeg'
file_name = 'image.jpeg'
# !wget -O $file_name https://www.boatingmag.com/wp-content/uploads/sites/16/2021/09/BTG0420-BOTY-Axopar-3.jpg
# Out:
# --2023-02-01 05:37:05--  https://www.boatingmag.com/wp-content/uploads/sites/16/2021/09/BTG0420-BOTY-Axopar-3.jpg
# Resolving www.boatingmag.com (www.boatingmag.com)... 141.193.213.20, 141.193.213.21
# Connecting to www.boatingmag.com (www.boatingmag.com)|141.193.213.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 352113 (344K) [image/jpeg]
# Saving to: ‘image.jpeg’
#
# image.jpeg          100%[===================>] 343.86K   868KB/s    in 0.4s
#
# 2023-02-01 05:37:06 (868 KB/s) - ‘image.jpeg’ saved [352113/352113]

# %%
sample_img = read_image(file_name)

sample_batch = torch.stack([sample_img])

# Convert the image tensor to the float type and move it to the device (GPU)
batch = convert_image_dtype(sample_batch, dtype=torch.float).to(device)

model = model.eval()

outputs = model(batch)
score_threshold = 0.5

# %%
# Loop through the input batch and model outputs
for img_int, output in zip(sample_batch, outputs):
  idxs = output['scores'] > score_threshold

# to get the final boxes
  boxes = torchvision.ops.nms(boxes = output['boxes'][idxs], 
                            scores = output['scores'][idxs], 
                            iou_threshold = 0.5)
  boxes_idxes = boxes.tolist()
  # Call the 'show_nms_boxes"
  show_nms_boxes(sample_batch, outputs, score_threshold)

# %%
# Download the image file from the URL and save it as 'image.jpeg'
file_name = 'image.jpeg'
# !wget -O $file_name https://i.ytimg.com/vi/jNj7wshXZdU/hqdefault.jpg
# Out:
# --2023-02-01 05:58:40--  https://i.ytimg.com/vi/jNj7wshXZdU/hqdefault.jpg
# Resolving i.ytimg.com (i.ytimg.com)... 142.251.10.119, 142.251.12.119, 172.217.194.119, ...
# Connecting to i.ytimg.com (i.ytimg.com)|142.251.10.119|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13622 (13K) [image/jpeg]
# Saving to: ‘image.jpeg’
#
# image.jpeg          100%[===================>]  13.30K  --.-KB/s    in 0s
#
# 2023-02-01 05:58:40 (96.3 MB/s) - ‘image.jpeg’ saved [13622/13622]

# %%
sample_img = read_image(file_name)

sample_batch = torch.stack([sample_img])

# Convert the image tensor to the float type and move it to the device (GPU)
batch = convert_image_dtype(sample_batch, dtype=torch.float).to(device)

model = model.eval()

outputs = model(batch)
# Set a score threshold to determine whether to keep or discard predictions
score_threshold = 0.5

# %%
# Loop through the input batch and model outputs
for img_int, output in zip(sample_batch, outputs):
  idxs = output['scores'] > score_threshold

  # to get the final boxes
  boxes = torchvision.ops.nms(boxes = output['boxes'][idxs], 
                            scores = output['scores'][idxs], 
                            iou_threshold = 0.3)
  boxes_idxes = boxes.tolist()
  
  # Call the 'show_nms_boxes"
  show_nms_boxes(sample_batch, outputs, score_threshold)

# %%
# Download the image file from the URL and save it as 'image.jpeg'
file_name = 'image.jpeg'
# !wget -O $file_name https://www.transatjacquesvabre.org/medias/01/36/13683/image-c-1180-664.jpg
# Out:
# --2023-02-01 05:37:08--  https://www.transatjacquesvabre.org/medias/01/36/13683/image-c-1180-664.jpg
# Resolving www.transatjacquesvabre.org (www.transatjacquesvabre.org)... 78.109.85.41
# Connecting to www.transatjacquesvabre.org (www.transatjacquesvabre.org)|78.109.85.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242637 (237K) [image/jpeg]
# Saving to: ‘image.jpeg’
#
# image.jpeg          100%[===================>] 236.95K   396KB/s    in 0.6s
#
# 2023-02-01 05:37:10 (396 KB/s) - ‘image.jpeg’ saved [242637/242637]

# %%
sample_img = read_image(file_name)

sample_batch = torch.stack([sample_img])
# Convert the image tensor to the float type and move it to the device (GPU)
batch = convert_image_dtype(sample_batch, dtype=torch.float).to(device)

model = model.eval()

outputs = model(batch)
# Set a score threshold to determine whether to keep or discard predictions
score_threshold = 0.5

# %%
# Loop through the input batch and model outputs
for img_int, output in zip(sample_batch, outputs):
  idxs = output['scores'] > score_threshold
    # to get the final boxes
  boxes = torchvision.ops.nms(boxes = output['boxes'][idxs], 
                            scores = output['scores'][idxs], 
                            iou_threshold = 0.5)
  boxes_idxes = boxes.tolist()
  # Call the 'show_nms_boxes"
  show_nms_boxes(sample_batch, outputs, score_threshold)

# %% [markdown]
# I think yes, I have a good accuracy in different weather, but to improve the accuarcy we should 1- Collect images of objects in different weather conditions, such as clear skies, rain, snow. This would help the model learn to recognize objects in a wide range of weather conditions. 2- Increase the number of images 3- Ensure that the dataset contains a balanced distribution of images in different weather conditions to avoid overfitting to a specific weather condition. 4- Include images of objects captured from different angles, distances, and in different lighting conditions to help the model learn to recognize objects in a wide range of scenarios.

# %% [markdown]
# ## Optional Exercise 10: Train another model of your choice
#
# To go deeper with object detection, you can try different models. A list of all available models is accessible in the [model zoo](https://pytorch.org/vision/stable/models.html).
#
# Do a benchmark of the three models used so far.
# What is the best accuracy ? best speed ? ...
